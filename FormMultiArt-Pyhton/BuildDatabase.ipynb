# %%
import csv
import pickle
import re  # string processing

# %%
# csv files
csv_path = 'csv\\'

csv_files = ['2012EPCG','2011SIACG','2010Interacao','2009EPCG','2008Interacao']
#csv_files = ['2008Interacao']
csv_extension = '.csv'

# %%
# pkl files and data structures
pkl_path = 'pkl\\'

# load the events data structure (if it exists)
events_fn = 'events.pkl'
events_modified = False

# verify if the file exists
try:
    with open(pkl_path+events_fn,"rb") as events_in:
        events = pickle.load(events_in)
except FileNotFoundError:
    events = []
print ('There are {0} events!'.format(len(events)))
#print (events)

# load the articles data structure (if it exists)
articles_fn = 'articles.pkl'
articles_modified = False

# verify if the file exists
try:
    with open(pkl_path+articles_fn,"rb") as articles_in:
        articles = pickle.load(articles_in)
except FileNotFoundError:
    articles = []
print ('There are {0} articles!'.format(len(articles)))
#print (articles)

# load the authors data structure (if it exists)
authors_fn = 'authors.pkl'
authors_modified = False

# verify if the file exists
try:
    with open(pkl_path+authors_fn,"rb") as authors_in:
        authors = pickle.load(authors_in)
except FileNotFoundError:
    authors = []
print ('There are {0} authors!'.format(len(authors)))
#print (authors)

# load the articles/authors data structure (if it exists)
art_aut_fn = 'art_aut.pkl'
art_aut_modified = False

# verify if the file exists
try:
    with open(pkl_path+art_aut_fn,"rb") as art_aut_in:
        art_aut = pickle.load(art_aut_in)
except FileNotFoundError:
    art_aut = []
print ('There are {0} articles-authors relationships!'.format(len(art_aut)))
#print (art_aut)

# load the forms data structure (if it exists)
forms_fn = 'forms.pkl'
forms_modified = False

# verify if the file exists
try:
    with open(pkl_path+forms_fn,"rb") as forms_in:
        forms = pickle.load(forms_in)
except FileNotFoundError:
    forms = []
print ('There are {0} forms!'.format(len(forms)))
#print (art_aut)
# Out:
# There are 0 events!
# There are 0 articles!
# There are 0 authors!
# There are 0 articles-authors relationships!
# There are 0 forms!

# %%
import time
import random
import hashlib
import unicodedata

# Use this function to generate a unique ID for each author
# use name as arg to generate more randomness

def guid( arg ):
    """
    Generates a universally unique ID.
    Any arguments only create more randomness.
    """
    t = int( time.time() * 1000 )
    r = int( random.random()*10000000 )
    data = str(t)+' '+str(r)+' '+arg
    data = unicodedata.normalize('NFKD', data).encode('ascii', 'ignore')
    #print (data, flush=True)
    data = hashlib.md5(data).hexdigest()

    return data

# %%
# main loop
for csv_file in csv_files:
    print ('*** Processing file {0} ***'.format(csv_file))
    
    csv_fileN = csv_path + csv_file + csv_extension    
    # read the csv file
    try:
        with open(csv_fileN,'rt') as csv_in:
            
            # Loop remaining rows
            for rownum, row in enumerate(csv.reader(csv_in, delimiter=";")):

                # for the first row get indexes of the required fields
                if rownum==0:
                    # event
                    Acronym_col = row.index ('Acronym')
                    Year_col = row.index ('Year')
                    Event_col = row.index ('Event')
                    # article
                    Type_col = row.index ('Type')
                    Title_col = row.index ('Title')
                    File_col = row.index ('File')
                    ArticleKey_col = row.index ('ArticleKey')
                    # authors col indexes
                    authors_col = []
                    au_n = 1
                    finish = False
                    while not finish:
                        LN = 'Author' + str(au_n) + 'LastName'
                        FN = 'Author' + str(au_n) + 'FirstName'
                        Contact = 'Author' + str(au_n) + 'Contact'
                        try:
                            LN_col = row.index (LN)
                            FN_col = row.index (FN)
                            contact_col = row.index (Contact)
                            authors_col.append((LN_col, FN_col, contact_col))
                            au_n += 1
                        except ValueError:
                            finish = True
                    continue
            
                # for the first data row verify the event
                if rownum==1:
                    Acronym = row[Acronym_col]
                    # verify if this event already exists in the events data structure
                    event_exists = False
                    for event in events:
                        if event['acr']==Acronym:
                            event_exists = True
                            break
                    if not event_exists:  # append event to events
                        event_dict = {'acr':Acronym, 'name':row[Event_col],
                                      'year':row[Year_col], 'state': 'loaded'}
                        events.append(event_dict)
                        events_modified = True
                        
                # for the current row (article)
                if row[Type_col]!='Article':
                    continue
                # article data
                ArticleKey = row[ArticleKey_col]
                print ("Processing article ... ", ArticleKey, end = ' ')
                # verify if this article already exists in the articles data structure
                article_exists = False
                for article in articles:
                    if article['ID']==ArticleKey:
                        article_exists = True
                        break
                if not article_exists:  # append event to articles
                    Acronym = row[Acronym_col]
                    Title = row[Title_col]
                    File = row[File_col]
                    art_dict = {'ID':ArticleKey, 'event':Acronym,
                           'title':Title, 'file':File, 'state':'loaded'}
                    articles.append(art_dict)
                    articles_modified = True
                    print ("added to articles")
                else:
                    print ("already in articles")
                # authors data
                this_authors = []
                for au in authors_col:
                    LN_col = au[0]
                    FN_col = au[1]
                    contact_col = au[2]
                    if row[LN_col]=="": break  # last author was previous
                    LN = row[LN_col]
                    LN = LN.strip()
                    LN = re.sub("\s\s+", " ", LN)
                    FN = row[FN_col]
                    FN = FN.strip()
                    FN = re.sub("\s\s+", " ", FN)
                    Name = FN+' '+LN
                    this_authors.append((Name,row[contact_col]))

                for aut in this_authors:                
                    AuthorName = aut[0]
                    AuthorContact = aut[1]
                    print ("\tProcessing author ... ", AuthorName, '(', AuthorContact,')', end = ' ')
                    # verify if this author already exists in the authors data structure
                    author_exists = False
                    for author in authors:
                        if author['name']==AuthorName:
                            author_exists = True
                            AuthorKey = author['ID']
                            print ("already in authors")
                            break
                    if not author_exists:  # append author to authors
                        AuthorKey = guid (AuthorName)
                        aut_dict = {'ID':AuthorKey, 'name':AuthorName,
                                   'email':AuthorContact, 'state':'loaded'}
                        authors.append(aut_dict)
                        authors_modified = True
                        print ("added to authors")
                    
                    # add to the art_aut table
                    # firstly check whether it already exists
                    art_aut_exists = False
                    for this_art_aut in art_aut:
                        if this_art_aut[0]==ArticleKey and this_art_aut[1]==AuthorKey:
                            art_aut_exists = True
                            break
                    if not art_aut_exists:  # add
                        art_aut.append((ArticleKey,AuthorKey))
                        art_aut_modified = True

                    # Forms
                    # there will only be a form for the current author
                    # if its email exists
                    if (AuthorContact.find('@') != -1):
                        # verify whether there is already a form for this author
                        form_exists = False
                        print ("\tProcessing form for author ", AuthorName, end = ' ...')
                        for form in forms:
                            if form['ID']==AuthorKey:
                                form_exists=True
                                form['articles'].append(ArticleKey)
                                forms_modified = True
                                print ("already in forms. Add article ", ArticleKey)
                        if not form_exists:
                            form_dict = {'ID':AuthorKey, 'articles':[ArticleKey],
                                        'file':AuthorName+'-form.pdf',
                                        'state':'loaded'}
                            forms.append(form_dict)
                            forms_modified = True
                            print ("added to forms. Add article ", ArticleKey)
                # end authors loop 
                print ()
                    
            # end loop through csv rows
        # end opening csv_in
    except FileNotFoundError:
        print ('File {0} not found!'.format(csv_fileN))
        continue
        
    print ('*** Finished file {0} ***\n'.format(csv_file))
    # end loop through csv files
# Out:
# *** Processing file 2012EPCG ***
# Processing article ...  2012_0006 added to articles
# 	Processing author ...  Abílio Costa ( amfcalt@gmail.com ) added to authors
# 	Processing form for author  Abílio Costa ...added to forms. Add article  2012_0006
# 	Processing author ...  João P. Pereira ( jjp@isep.ipp.pt  ) added to authors
# 	Processing form for author  João P. Pereira ...added to forms. Add article  2012_0006
#
# Processing article ...  2012_0007 added to articles
# 	Processing author ...  Pedro Leitão ( pedromiguel_rs70@hotmail.com  ) added to authors
# 	Processing form for author  Pedro Leitão ...added to forms. Add article  2012_0007
# 	Processing author ...  António Castro ( avc@isep.ipp.pt  ) added to authors
# 	Processing form for author  António Castro ...added to forms. Add article  2012_0007
# 	Processing author ...  João J. Pereira ( jjp@isep.ipp.pt ) added to authors
# 	Processing form for author  João J. Pereira ...added to forms. Add article  2012_0007
#
# Processing article ...  2012_0008 added to articles
# 	Processing author ...  Mourato Fausto ( p21748@campus.fct.unl.pt  ) added to authors
# 	Processing form for author  Mourato Fausto ...added to forms. Add article  2012_0008
# 	Processing author ...  Fernando Birra ( fpb@di.fct.unl.pt  ) added to authors
# 	Processing form for author  Fernando Birra ...added to forms. Add article  2012_0008
# 	Processing author ...  Manuel Próspero Santos ( ps@di.fct.unl.pt ) added to authors
# 	Processing form for author  Manuel Próspero Santos ...added to forms. Add article  2012_0008
#
# Processing article ...  2012_0009 added to articles
# 	Processing author ...  Bruno Preto ( bpreto@gmail.com ) added to authors
# 	Processing form for author  Bruno Preto ...added to forms. Add article  2012_0009
# 	Processing author ...  Fernando Birra ( fpb@di.fct.unl.pt  ) already in authors
# 	Processing form for author  Fernando Birra ...already in forms. Add article  2012_0009
# 	Processing author ...  Pedro Medeiros ( pdm@fct.unl.pt ) added to authors
# 	Processing form for author  Pedro Medeiros ...added to forms. Add article  2012_0009
#
# Processing article ...  2012_0010 added to articles
# 	Processing author ...  Nuno Silva ( nuno.silva@ccg.pt ) added to authors
# 	Processing form for author  Nuno Silva ...added to forms. Add article  2012_0010
# 	Processing author ...  Luís Paulo Santos ( psantos@di.uminho.pt ) added to authors
# 	Processing form for author  Luís Paulo Santos ...added to forms. Add article  2012_0010
#
# Processing article ...  2012_0011 added to articles
# 	Processing author ...  Tânia Pinheiro ( fc28181@alunos.fc.ul.pt ) added to authors
# 	Processing form for author  Tânia Pinheiro ...added to forms. Add article  2012_0011
# 	Processing author ...  Ana Paula Cláudio ( apc@fc.ul.pt  ) added to authors
# 	Processing form for author  Ana Paula Cláudio ...added to forms. Add article  2012_0011
# 	Processing author ...  Maria Beatriz Carmo ( bc@fc.ul.pt  ) added to authors
# 	Processing form for author  Maria Beatriz Carmo ...added to forms. Add article  2012_0011
#
# Processing article ...  2012_0012 added to articles
# 	Processing author ...  Carlos Campos ( crc@isep.ipp.pt  ) added to authors
# 	Processing form for author  Carlos Campos ...added to forms. Add article  2012_0012
# 	Processing author ...  João Miguel Leitão ( jml@isep.ipp.pt ) added to authors
# 	Processing form for author  João Miguel Leitão ...added to forms. Add article  2012_0012
# 	Processing author ...  António Fernando Coelho ( acoelho@fe.up.pt ) added to authors
# 	Processing form for author  António Fernando Coelho ...added to forms. Add article  2012_0012
#
# Processing article ...  2012_0013 added to articles
# 	Processing author ...  Raquel Costa ( rgcc@ist.utl.pt  ) added to authors
# 	Processing form for author  Raquel Costa ...added to forms. Add article  2012_0013
# 	Processing author ...  Manuel J. Fonseca ( mjf@inesc-id.pt ) added to authors
# 	Processing form for author  Manuel J. Fonseca ...added to forms. Add article  2012_0013
# 	Processing author ...  Alfredo Ferreira ( alfredo.ferreira@inesc-id.pt ) added to authors
# 	Processing form for author  Alfredo Ferreira ...added to forms. Add article  2012_0013
#
# Processing article ...  2012_0014 added to articles
# 	Processing author ...  Vasco Costa ( vasc@vimmi.inesc-id.pt ) added to authors
# 	Processing form for author  Vasco Costa ...added to forms. Add article  2012_0014
# 	Processing author ...  João M. Pereira ( jap@vimmi.inesc-id.pt ) added to authors
# 	Processing form for author  João M. Pereira ...added to forms. Add article  2012_0014
# 	Processing author ...  Joaquim A. Jorge ( jaj@vimmi.inesc-id.pt ) added to authors
# 	Processing form for author  Joaquim A. Jorge ...added to forms. Add article  2012_0014
#
# Processing article ...  2012_0015 added to articles
# 	Processing author ...  Maria Beatriz Carmo ( bc@di.fc.ul.pt ) already in authors
# 	Processing form for author  Maria Beatriz Carmo ...already in forms. Add article  2012_0015
# 	Processing author ...  Ana Paula Cláudio ( apc@di.fc.ul.pt ) already in authors
# 	Processing form for author  Ana Paula Cláudio ...already in forms. Add article  2012_0015
# 	Processing author ...  António Ferreira ( asfe@di.fc.ul.pt ) added to authors
# 	Processing form for author  António Ferreira ...added to forms. Add article  2012_0015
# 	Processing author ...  Ana Paula Afonso ( apa@di.fc.ul.pt ) added to authors
# 	Processing form for author  Ana Paula Afonso ...added to forms. Add article  2012_0015
# 	Processing author ...  Edgar Montez (  fc35956@alunos.fc.ul.pt ) added to authors
# 	Processing form for author  Edgar Montez ...added to forms. Add article  2012_0015
# 	Processing author ...  Raúl Simplício (  rjsimplicio@fc.ul.pt  ) added to authors
# 	Processing form for author  Raúl Simplício ...added to forms. Add article  2012_0015
#
# Processing article ...  2012_0016 added to articles
# 	Processing author ...  Igor Duarte Cardoso ( idc@ua.pt ) added to authors
# 	Processing form for author  Igor Duarte Cardoso ...added to forms. Add article  2012_0016
# 	Processing author ...  Paulo Dias ( paulo.dias@ua.pt ) added to authors
# 	Processing form for author  Paulo Dias ...added to forms. Add article  2012_0016
# 	Processing author ...  Beatriz Sousa Santos ( bss@ua.pt ) added to authors
# 	Processing form for author  Beatriz Sousa Santos ...added to forms. Add article  2012_0016
#
# Processing article ...  2012_0017 added to articles
# 	Processing author ...  Telmo Adão ( telmo.adao@gmail.com ) added to authors
# 	Processing form for author  Telmo Adão ...added to forms. Add article  2012_0017
# 	Processing author ...  Luís Magalhães ( lmagalha@utad.pt  ) added to authors
# 	Processing form for author  Luís Magalhães ...added to forms. Add article  2012_0017
# 	Processing author ...  Maximino Bessa ( maxbessa@utad.pt  ) added to authors
# 	Processing form for author  Maximino Bessa ...added to forms. Add article  2012_0017
# 	Processing author ...  António Coelho ( acoelho@fe.up.pt  ) added to authors
# 	Processing form for author  António Coelho ...added to forms. Add article  2012_0017
# 	Processing author ...  Augusto Sousa ( augusto.sousa@fe.up.pt ) added to authors
# 	Processing form for author  Augusto Sousa ...added to forms. Add article  2012_0017
# 	Processing author ...  Nuno Rodrigues ( nunorod@ipleiria.pt  ) added to authors
# 	Processing form for author  Nuno Rodrigues ...added to forms. Add article  2012_0017
# 	Processing author ...  Alexandrino Gonçalves ( alexi@ipleiria.pt  ) added to authors
# 	Processing form for author  Alexandrino Gonçalves ...added to forms. Add article  2012_0017
# 	Processing author ...  Roberto Rodrigues ( rmfmrodrigues@gmail.com  ) added to authors
# 	Processing form for author  Roberto Rodrigues ...added to forms. Add article  2012_0017
# 	Processing author ...  Francisco Pereira ( fsp@utad.pt ) added to authors
# 	Processing form for author  Francisco Pereira ...added to forms. Add article  2012_0017
# 	Processing author ...  João Moura ( jpmoura@utad.pt  ) added to authors
# 	Processing form for author  João Moura ...added to forms. Add article  2012_0017
# 	Processing author ...  Luís Paulo Reis ( lpreis@fe.up.pt ) added to authors
# 	Processing form for author  Luís Paulo Reis ...added to forms. Add article  2012_0017
#
# Processing article ...  2012_0019 added to articles
# 	Processing author ...  Madalena Ribeiro ( mribeiro@ipcb.pt  ) added to authors
# 	Processing form for author  Madalena Ribeiro ...added to forms. Add article  2012_0019
# 	Processing author ...  Abel Gomes ( agomes@di.ubi.pt ) added to authors
# 	Processing form for author  Abel Gomes ...added to forms. Add article  2012_0019
#
# Processing article ...  2012_0020 added to articles
# 	Processing author ...  Rui Nóbrega ( rui.nobrega@campus.fct.unl.pt ) added to authors
# 	Processing form for author  Rui Nóbrega ...added to forms. Add article  2012_0020
# 	Processing author ...  Nuno Corrreia ( nmc@fct.unl.pt ) added to authors
# 	Processing form for author  Nuno Corrreia ...added to forms. Add article  2012_0020
#
# Processing article ...  2012_0021 added to articles
# 	Processing author ...  Ricardo Dias ( ricardo.dias@ist.utl.pt ) added to authors
# 	Processing form for author  Ricardo Dias ...added to forms. Add article  2012_0021
# 	Processing author ...  Manuel J. Fonseca (  mjf@inesc-id.pt ) already in authors
# 	Processing form for author  Manuel J. Fonseca ...already in forms. Add article  2012_0021
# 	Processing author ...  Daniel Gonçalves ( daniel.goncalves@inesc-id.pt ) added to authors
# 	Processing form for author  Daniel Gonçalves ...added to forms. Add article  2012_0021
#
# Processing article ...  2012_0022 added to articles
# 	Processing author ...  António Coelho ( acoelho@fe.up.pt ) already in authors
# 	Processing form for author  António Coelho ...already in forms. Add article  2012_0022
# 	Processing author ...  Ricardo Gonçalves ( refg@inescporto.pt ) added to authors
# 	Processing form for author  Ricardo Gonçalves ...added to forms. Add article  2012_0022
# 	Processing author ...  Rui Rodrigues (  rui.rodrigues@fe.up.pt ) added to authors
# 	Processing form for author  Rui Rodrigues ...added to forms. Add article  2012_0022
#
# Processing article ...  2012_0023 added to articles
# 	Processing author ...  Gustavo Maçães ( gustavo.macaes@ccg.pt  ) added to authors
# 	Processing form for author  Gustavo Maçães ...added to forms. Add article  2012_0023
# 	Processing author ...  Hugo Domingues ( hugo@ccg.pt  ) added to authors
# 	Processing form for author  Hugo Domingues ...added to forms. Add article  2012_0023
# 	Processing author ...  Luís Almeida ( luis.almeida@ccg.pt  ) added to authors
# 	Processing form for author  Luís Almeida ...added to forms. Add article  2012_0023
# 	Processing author ...  Luís Paulo Santos ( psantos@di.uminho.pt  ) already in authors
# 	Processing form for author  Luís Paulo Santos ...already in forms. Add article  2012_0023
#
# Processing article ...  2012_0024 added to articles
# 	Processing author ...  Pedro Ribeiro ( pedro.ribeiro@ccg.pt  ) added to authors
# 	Processing form for author  Pedro Ribeiro ...added to forms. Add article  2012_0024
# 	Processing author ...  Ido Iurgel Rhine ( Ido.Iurgel@hochschule-rhein-waal.de  ) added to authors
# 	Processing form for author  Ido Iurgel Rhine ...added to forms. Add article  2012_0024
#
# Processing article ...  2012_0026 added to articles
# 	Processing author ...  João Ferreira Nunes ( joao.nunes@estg.ipvc.pt ) added to authors
# 	Processing form for author  João Ferreira Nunes ...added to forms. Add article  2012_0026
# 	Processing author ...  Pedro Miguel Moreira ( pmoreira@estg.ipvc.pt ) added to authors
# 	Processing form for author  Pedro Miguel Moreira ...added to forms. Add article  2012_0026
# 	Processing author ...  João Manuel R. S. Tavares ( tavares@fe.up.pt  ) added to authors
# 	Processing form for author  João Manuel R. S. Tavares ...added to forms. Add article  2012_0026
#
# Processing article ...  2012_0027 added to articles
# 	Processing author ...  J. M. Brisson Lopes ( brisson@ist.utl.pt  ) added to authors
# 	Processing form for author  J. M. Brisson Lopes ...added to forms. Add article  2012_0027
#
# Processing article ...  2012_0028 added to articles
# 	Processing author ...  Nuno Cardoso ( nunocardoso83@gmail.com  ) added to authors
# 	Processing form for author  Nuno Cardoso ...added to forms. Add article  2012_0028
# 	Processing author ...  Fábio Rocha ( fabioalvesrocha@gmail.com ) added to authors
# 	Processing form for author  Fábio Rocha ...added to forms. Add article  2012_0028
# 	Processing author ...  Pedro Miguel Moreira ( pmoreira@estg.ipvc.pt  ) already in authors
# 	Processing form for author  Pedro Miguel Moreira ...already in forms. Add article  2012_0028
#
# Processing article ...  2012_0029 added to articles
# 	Processing author ...  João Fonseca ( pg18976@alunos.uminho.pt ) added to authors
# 	Processing form for author  João Fonseca ...added to forms. Add article  2012_0029
# 	Processing author ...  Gilberto Felgueiras ( pg21000@alunos.uminho.pt ) added to authors
# 	Processing form for author  Gilberto Felgueiras ...added to forms. Add article  2012_0029
# 	Processing author ...  Pedro Miguel Moreira ( pmoreira@estg.ipvc.pt  ) already in authors
# 	Processing form for author  Pedro Miguel Moreira ...already in forms. Add article  2012_0029
#
# Processing article ...  2012_0030 added to articles
# 	Processing author ...  Ricardo Batista ( ricardjose@fe.up.pt ) added to authors
# 	Processing form for author  Ricardo Batista ...added to forms. Add article  2012_0030
# 	Processing author ...  Luís Paulo Reis ( lpreis@dsi.uminho.pt  ) already in authors
# 	Processing form for author  Luís Paulo Reis ...already in forms. Add article  2012_0030
# 	Processing author ...  Luís Magalhães ( lmagalha@utad.pt ) already in authors
# 	Processing form for author  Luís Magalhães ...already in forms. Add article  2012_0030
# 	Processing author ...  Roberto Rodrigues ( roberto@fe.up.pt  ) already in authors
# 	Processing form for author  Roberto Rodrigues ...already in forms. Add article  2012_0030
#
# Processing article ...  2012_0031 added to articles
# 	Processing author ...  Waldir Pimenta ( wpimenta@di.uminho.pt  ) added to authors
# 	Processing form for author  Waldir Pimenta ...added to forms. Add article  2012_0031
#
# *** Finished file 2012EPCG ***
#
# *** Processing file 2011SIACG ***
# Processing article ...  2011_0011 added to articles
# 	Processing author ...  Javier Novo Rodríguez (  ) added to authors
# 	Processing author ...  Elena Hernández Pereira ( elena.hernandez@udc.es ) added to authors
# 	Processing form for author  Elena Hernández Pereira ...added to forms. Add article  2011_0011
# 	Processing author ...  Mariano Cabrero Canosa ( mariano.cabrero@udc.es ) added to authors
# 	Processing form for author  Mariano Cabrero Canosa ...added to forms. Add article  2011_0011
#
# Processing article ...  2011_0012 added to articles
# 	Processing author ...  Vítor Gonçalves (  ) added to authors
# 	Processing author ...  Fernando Almeida ( falm@geo.ua.pt ) added to authors
# 	Processing form for author  Fernando Almeida ...added to forms. Add article  2011_0012
# 	Processing author ...  Joaquim Madeira ( jmadeira@ua.pt ) added to authors
# 	Processing form for author  Joaquim Madeira ...added to forms. Add article  2011_0012
# 	Processing author ...  Beatriz Sousa Santos ( bss@ua.pt ) already in authors
# 	Processing form for author  Beatriz Sousa Santos ...already in forms. Add article  2011_0012
#
# Processing article ...  2011_0013 added to articles
# 	Processing author ...  André Riboira (  ) added to authors
# 	Processing author ...  Rui Rodrigues ( rui.rodrigues@fe.up.pt ) already in authors
# 	Processing form for author  Rui Rodrigues ...already in forms. Add article  2011_0013
# 	Processing author ...  Rui Abreu ( rui@computer.org ) added to authors
# 	Processing form for author  Rui Abreu ...added to forms. Add article  2011_0013
#
# Processing article ...  2011_0014 added to articles
# 	Processing author ...  Lindomar Rocha (  ) added to authors
# 	Processing author ...  Rui Rodrigues ( rui.rodrigues@fe.up.pt ) already in authors
# 	Processing form for author  Rui Rodrigues ...already in forms. Add article  2011_0014
#
# Processing article ...  2011_0015 added to articles
# 	Processing author ...  Laura Raya ( laura.raya@u-tad.com ) added to authors
# 	Processing form for author  Laura Raya ...added to forms. Add article  2011_0015
# 	Processing author ...  Miguel A. Otaduy ( miguel.otaduy@urjc.es ) added to authors
# 	Processing form for author  Miguel A. Otaduy ...added to forms. Add article  2011_0015
# 	Processing author ...  Marcos García ( marcos.garcia@urjc.es ) added to authors
# 	Processing form for author  Marcos García ...added to forms. Add article  2011_0015
#
# Processing article ...  2011_0016 added to articles
# 	Processing author ...  J. M. Brisson Lopes ( brisson@tecnico.ulisboa.pt ) already in authors
# 	Processing form for author  J. M. Brisson Lopes ...already in forms. Add article  2011_0016
#
# Processing article ...  2011_0018 added to articles
# 	Processing author ...  C. Andujar ( andujar@cs.upc.edu ) added to authors
# 	Processing form for author  C. Andujar ...added to forms. Add article  2011_0018
#
# Processing article ...  2011_0019 added to articles
# 	Processing author ...  J. Blasco ( jblasco@ai2.upv.es  ) added to authors
# 	Processing form for author  J. Blasco ...added to forms. Add article  2011_0019
# 	Processing author ...  F. Abad ( fjabad@dsic.upv.es ) added to authors
# 	Processing form for author  F. Abad ...added to forms. Add article  2011_0019
# 	Processing author ...  E. Camahort ( camahort@dsic.upv.es ) added to authors
# 	Processing form for author  E. Camahort ...added to forms. Add article  2011_0019
# 	Processing author ...  R. Vivó ( rvivo@dsic.upv.es ) added to authors
# 	Processing form for author  R. Vivó ...added to forms. Add article  2011_0019
#
# Processing article ...  2011_0020 added to articles
# 	Processing author ...  Elena Garces ( elena.garces@seddi.com ) added to authors
# 	Processing form for author  Elena Garces ...added to forms. Add article  2011_0020
# 	Processing author ...  Diego Gutierrez ( diegog@unizar.es ) added to authors
# 	Processing form for author  Diego Gutierrez ...added to forms. Add article  2011_0020
# 	Processing author ...  Jorge Lopez Moreno ( jorge.lopez@urjc.es ) added to authors
# 	Processing form for author  Jorge Lopez Moreno ...added to forms. Add article  2011_0020
#
# Processing article ...  2011_0021 added to articles
# 	Processing author ...  Adrian Jarabo (  ) added to authors
# 	Processing author ...  Belen Masia (  bmasia@unizar.es ) added to authors
# 	Processing form for author  Belen Masia ...added to forms. Add article  2011_0021
# 	Processing author ...  Diego Gutierrez ( diegog@unizar.es ) already in authors
# 	Processing form for author  Diego Gutierrez ...already in forms. Add article  2011_0021
#
# Processing article ...  2011_0022 added to articles
# 	Processing author ...  J.M.F. Rodrigues ( jrodrig@ualg.pt ) added to authors
# 	Processing form for author  J.M.F. Rodrigues ...added to forms. Add article  2011_0022
# 	Processing author ...  R. Lam (  rlam@ualg.pt ) added to authors
# 	Processing form for author  R. Lam ...added to forms. Add article  2011_0022
# 	Processing author ...  J.M.H. du Buf ( dubuf@ualg.pt ) added to authors
# 	Processing form for author  J.M.H. du Buf ...added to forms. Add article  2011_0022
#
# Processing article ...  2011_0024 added to articles
# 	Processing author ...  Jorge Gascón ( jorge.gascon.perez@gmail.com ) added to authors
# 	Processing form for author  Jorge Gascón ...added to forms. Add article  2011_0024
# 	Processing author ...  José M. Bayona (  ) added to authors
# 	Processing author ...  José M. Espadero ( josemiguel.espadero@urjc.es ) added to authors
# 	Processing form for author  José M. Espadero ...added to forms. Add article  2011_0024
# 	Processing author ...  Miguel A. Otaduy ( miguel.otaduy@urjc.es ) already in authors
# 	Processing form for author  Miguel A. Otaduy ...already in forms. Add article  2011_0024
#
# Processing article ...  2011_0025 added to articles
# 	Processing author ...  Belen Masia ( bmasia@unizar.es ) already in authors
# 	Processing form for author  Belen Masia ...already in forms. Add article  2011_0025
# 	Processing author ...  Adrian Corrales ( acorrom@gmail.com ) added to authors
# 	Processing form for author  Adrian Corrales ...added to forms. Add article  2011_0025
# 	Processing author ...  Lara Presa ( larapresa@gmail.com ) added to authors
# 	Processing form for author  Lara Presa ...added to forms. Add article  2011_0025
# 	Processing author ...  Diego Gutierrez ( diegog@unizar.es ) already in authors
# 	Processing form for author  Diego Gutierrez ...already in forms. Add article  2011_0025
#
# Processing article ...  2011_0026 added to articles
# 	Processing author ...  Jose I. Echevarria ( echevarr@adobe.com ) added to authors
# 	Processing form for author  Jose I. Echevarria ...added to forms. Add article  2011_0026
# 	Processing author ...  Diego Gutierrez ( diegog@unizar.es ) already in authors
# 	Processing form for author  Diego Gutierrez ...already in forms. Add article  2011_0026
#
# Processing article ...  2011_0027 added to articles
# 	Processing author ...  Celso P. Costa (  ) added to authors
# 	Processing author ...  José I. J. Rodrigues (  ) added to authors
# 	Processing author ...  Mauro J. G. Figueiredo ( mfiguei@ualg.pt ) added to authors
# 	Processing form for author  Mauro J. G. Figueiredo ...added to forms. Add article  2011_0027
#
# Processing article ...  2011_0028 added to articles
# 	Processing author ...  Tiago Gonçalves (  ) added to authors
# 	Processing author ...  Ana Paula Afonso ( apafonso@ciencias . ulisboa . pt ) already in authors
# 	Processing form for author  Ana Paula Afonso ...already in forms. Add article  2011_0028
# 	Processing author ...  Maria Beatriz Carmo ( bc@di.fc.ul.pt ) already in authors
# 	Processing form for author  Maria Beatriz Carmo ...already in forms. Add article  2011_0028
# 	Processing author ...  Paulo Pombinho ( pmimatos@ciencias.ulisboa.pt ) added to authors
# 	Processing form for author  Paulo Pombinho ...added to forms. Add article  2011_0028
#
# Processing article ...  2011_0029 added to articles
# 	Processing author ...  Armando de la Re (  ) added to authors
# 	Processing author ...  Eduardo Martorell (  ) added to authors
# 	Processing author ...  Emilio Camahort ( camahort@dsic.upv.es ) added to authors
# 	Processing form for author  Emilio Camahort ...added to forms. Add article  2011_0029
# 	Processing author ...  Francisco Abad ( fjabad@dsic.upv.es ) added to authors
# 	Processing form for author  Francisco Abad ...added to forms. Add article  2011_0029
#
# Processing article ...  2011_0031 added to articles
# 	Processing author ...  G. Amador (  ) added to authors
# 	Processing author ...  A. Gomes ( agomes@di.ubi.pt ) added to authors
# 	Processing form for author  A. Gomes ...added to forms. Add article  2011_0031
#
# Processing article ...  2011_0032 added to articles
# 	Processing author ...  Gustavo Patow ( dagush@imae.udg.edu ) added to authors
# 	Processing form for author  Gustavo Patow ...added to forms. Add article  2011_0032
#
# Processing article ...  2011_0033 added to articles
# 	Processing author ...  G. Vélez (  ) added to authors
# 	Processing author ...  L. Mate (  ) added to authors
# 	Processing author ...  A. Amundarain ( aamundarain@ceit.es ) added to authors
# 	Processing form for author  A. Amundarain ...added to forms. Add article  2011_0033
# 	Processing author ...  F. Ordás (  ) added to authors
# 	Processing author ...  J.A. Marín (  ) added to authors
#
# Processing article ...  2011_0034 added to articles
# 	Processing author ...  J. van Gestel (  ) added to authors
# 	Processing author ...  R. Bidarra ( R.Bidarra@tudelft.nl ) added to authors
# 	Processing form for author  R. Bidarra ...added to forms. Add article  2011_0034
#
# Processing article ...  2011_0035 added to articles
# 	Processing author ...  Eduardo Roa ( eduroam@gmail.com ) added to authors
# 	Processing form for author  Eduardo Roa ...added to forms. Add article  2011_0035
# 	Processing author ...  Víctor Theoktisto (  ) added to authors
# 	Processing author ...  Marta Fairén ( mfairen@lsi.upc.edu ) added to authors
# 	Processing form for author  Marta Fairén ...added to forms. Add article  2011_0035
# 	Processing author ...  Isabel Navazo ( isabel@lsi.upc.edu ) added to authors
# 	Processing form for author  Isabel Navazo ...added to forms. Add article  2011_0035
#
# Processing article ...  2011_0036 added to articles
# 	Processing author ...  Marcos Novalbos (  ) added to authors
# 	Processing author ...  Alberto Sánchez ( alberto.sanchez@urjc.es ) added to authors
# 	Processing form for author  Alberto Sánchez ...added to forms. Add article  2011_0036
#
# Processing article ...  2011_0038 added to articles
# 	Processing author ...  Fernando Hernández ( fernando.pinto@urjc.es ) added to authors
# 	Processing form for author  Fernando Hernández ...added to forms. Add article  2011_0038
# 	Processing author ...  Carlos Garre ( carlos.garre@uc3m.es ) added to authors
# 	Processing form for author  Carlos Garre ...added to forms. Add article  2011_0038
# 	Processing author ...  Rubén Casillas (  ) added to authors
# 	Processing author ...  Miguel A. Otaduy ( miguel.otaduy@urjc.es ) already in authors
# 	Processing form for author  Miguel A. Otaduy ...already in forms. Add article  2011_0038
#
# Processing article ...  2011_0039 added to articles
# 	Processing author ...  Francisco J. R. Prados (  ) added to authors
# 	Processing author ...  Alejandro León Salas ( aleon@ugr.es ) added to authors
# 	Processing form for author  Alejandro León Salas ...added to forms. Add article  2011_0039
# 	Processing author ...  Juan Carlos Torres ( jctorres@ugr.es ) added to authors
# 	Processing form for author  Juan Carlos Torres ...added to forms. Add article  2011_0039
#
# Processing article ...  2011_0040 added to articles
# 	Processing author ...  J. Ortegano (  ) added to authors
# 	Processing author ...  H. Navarro (  ) added to authors
# 	Processing author ...  R. Carmona ( rhadames.carmona@ciens.ucv.ve ) added to authors
# 	Processing form for author  R. Carmona ...added to forms. Add article  2011_0040
#
# Processing article ...  2011_0041 added to articles
# 	Processing author ...  Luis F. A. Silva (  ) added to authors
# 	Processing author ...  Frutuoso G. M. Silva ( fgmsilva@ubi.pt ) added to authors
# 	Processing form for author  Frutuoso G. M. Silva ...added to forms. Add article  2011_0041
#
# Processing article ...  2011_0042 added to articles
# 	Processing author ...  E.A. Leal ( esleal@uac.edu.co ) added to authors
# 	Processing form for author  E.A. Leal ...added to forms. Add article  2011_0042
# 	Processing author ...  N.E. Leal ( nleal@uninorte.edu.co ) added to authors
# 	Processing form for author  N.E. Leal ...added to forms. Add article  2011_0042
#
# Processing article ...  2011_0043 added to articles
# 	Processing author ...  M. Melo ( miguel.c.melo@inesctec.pt ) added to authors
# 	Processing form for author  M. Melo ...added to forms. Add article  2011_0043
# 	Processing author ...  P. B. Silva (  ) added to authors
# 	Processing author ...  M. Bessa ( maxbessa.utad@gmail.com ) added to authors
# 	Processing form for author  M. Bessa ...added to forms. Add article  2011_0043
# 	Processing author ...  A. Coelho (  ) added to authors
# 	Processing author ...  J. Moura (  ) added to authors
# 	Processing author ...  A. Rocha (  ) added to authors
# 	Processing author ...  F. Ferreira (  ) added to authors
# 	Processing author ...  J. Cruz (  ) added to authors
# 	Processing author ...  A. A. Sousa (  ) added to authors
#
# Processing article ...  2011_0045 added to articles
# 	Processing author ...  Esmitt Ramírez Ramírez ( esmitt.ramirez@ciens.ucv.ve ) added to authors
# 	Processing form for author  Esmitt Ramírez Ramírez ...added to forms. Add article  2011_0045
# 	Processing author ...  Ernesto Coto ( ecoto@ciens.ucv.ve ) added to authors
# 	Processing form for author  Ernesto Coto ...added to forms. Add article  2011_0045
#
# Processing article ...  2011_0046 added to articles
# 	Processing author ...  Paula Martins ( pmartins@ua.pt ) added to authors
# 	Processing form for author  Paula Martins ...added to forms. Add article  2011_0046
# 	Processing author ...  Samuel Silva ( sss@ua.pt ) added to authors
# 	Processing form for author  Samuel Silva ...added to forms. Add article  2011_0046
# 	Processing author ...  Catarina Oliveira (  ) added to authors
# 	Processing author ...  Carlos Ferreira (  ) added to authors
# 	Processing author ...  Augusto Silva (  ) added to authors
# 	Processing author ...  António Teixeira ( ajst@det.ua.pt ) added to authors
# 	Processing form for author  António Teixeira ...added to forms. Add article  2011_0046
#
# Processing article ...  2011_0047 added to articles
# 	Processing author ...  Samuel Silva ( sss@ua.pt ) already in authors
# 	Processing form for author  Samuel Silva ...already in forms. Add article  2011_0047
# 	Processing author ...  Beatriz Sousa Santos ( bss@ua.pt ) already in authors
# 	Processing form for author  Beatriz Sousa Santos ...already in forms. Add article  2011_0047
# 	Processing author ...  Joaquim Madeira ( jmadeira@ua.pt ) already in authors
# 	Processing form for author  Joaquim Madeira ...already in forms. Add article  2011_0047
#
# Processing article ...  2011_0048 added to articles
# 	Processing author ...  P. Coelho (  ) added to authors
# 	Processing author ...  A. Cunha (  ) added to authors
# 	Processing author ...  P. Costa (  ) added to authors
# 	Processing author ...  L. Hadjileontiadis ( leontios@auth.gr ) added to authors
# 	Processing form for author  L. Hadjileontiadis ...added to forms. Add article  2011_0048
#
# Processing article ...  2011_0049 added to articles
# 	Processing author ...  L. Landaeta (  ) added to authors
# 	Processing author ...  A. La Cruz (  ) added to authors
#
# *** Finished file 2011SIACG ***
#
# *** Processing file 2010Interacao ***
# Processing article ...  2010_0011 added to articles
# 	Processing author ...  Tiago Gomes ( tagomes@lasige.di.fc.ul.pt ) added to authors
# 	Processing form for author  Tiago Gomes ...added to forms. Add article  2010_0011
# 	Processing author ...  Carlos Duarte ( cad@di.fc.ul.pt ) added to authors
# 	Processing form for author  Carlos Duarte ...added to forms. Add article  2010_0011
# 	Processing author ...  Luis Carriço ( lmc@di.fc.ul.pt ) added to authors
# 	Processing form for author  Luis Carriço ...added to forms. Add article  2010_0011
# 	Processing author ...  Joana Neca ( jneca@di.fc.ul.pt ) added to authors
# 	Processing form for author  Joana Neca ...added to forms. Add article  2010_0011
# 	Processing author ...  Tiago Reis ( treis@lasige.di.fc.ul.pt ) added to authors
# 	Processing form for author  Tiago Reis ...added to forms. Add article  2010_0011
#
# Processing article ...  2010_0012 added to articles
# 	Processing author ...  Bruno Araújo ( brar@vimmi.inesc-id.pt ) added to authors
# 	Processing form for author  Bruno Araújo ...added to forms. Add article  2010_0012
# 	Processing author ...  Diogo Mariano ( diogo.mariano@ist.utl.pt ) added to authors
# 	Processing form for author  Diogo Mariano ...added to forms. Add article  2010_0012
# 	Processing author ...  Ricardo Jota ( jota@vimmi.inesc-id.pt ) added to authors
# 	Processing form for author  Ricardo Jota ...added to forms. Add article  2010_0012
# 	Processing author ...  Alfredo Ferreira ( afj@vimmi.inesc-id.pt    ) already in authors
# 	Processing form for author  Alfredo Ferreira ...already in forms. Add article  2010_0012
# 	Processing author ...  Joaquim Jorge ( jaj@vimmi.inesc-id.pt    ) added to authors
# 	Processing form for author  Joaquim Jorge ...added to forms. Add article  2010_0012
#
# Processing article ...  2010_0013 added to articles
# 	Processing author ...  Pedro A. Lopes ( pedro.lopes@ist.utl.pt ) added to authors
# 	Processing form for author  Pedro A. Lopes ...added to forms. Add article  2010_0013
# 	Processing author ...  J.A. Madeiras Pereira ( jap@inesc-id.pt ) added to authors
# 	Processing form for author  J.A. Madeiras Pereira ...added to forms. Add article  2010_0013
# 	Processing author ...  Alfredo Ferreira ( alfredo.ferreira@inesc-id.pt ) already in authors
# 	Processing form for author  Alfredo Ferreira ...already in forms. Add article  2010_0013
#
# Processing article ...  2010_0015 added to articles
# 	Processing author ...  João M Brisson Lopes ( brisson@ist.utl.pt  ) added to authors
# 	Processing form for author  João M Brisson Lopes ...added to forms. Add article  2010_0015
#
# Processing article ...  2010_0016 added to articles
# 	Processing author ...  Rui Palha ( ruipalha@ua.pt ) added to authors
# 	Processing form for author  Rui Palha ...added to forms. Add article  2010_0016
# 	Processing author ...  Paulo Dias ( paulo.dias@ua.pt  ) already in authors
# 	Processing form for author  Paulo Dias ...already in forms. Add article  2010_0016
# 	Processing author ...  Rui A. Costa ( rcosta@ubiwhere.com ) added to authors
# 	Processing form for author  Rui A. Costa ...added to forms. Add article  2010_0016
# 	Processing author ...  Beatriz Sousa Santos ( bss@ua.pt ) already in authors
# 	Processing form for author  Beatriz Sousa Santos ...already in forms. Add article  2010_0016
#
# Processing article ...  2010_0017 added to articles
# 	Processing author ...  Luís Duarte ( lduarte@lasige.di.fc.ul.pt  ) added to authors
# 	Processing form for author  Luís Duarte ...added to forms. Add article  2010_0017
# 	Processing author ...  Marco Sá ( marcosa@di.fc.ul.pt ) added to authors
# 	Processing form for author  Marco Sá ...added to forms. Add article  2010_0017
# 	Processing author ...  Luís Carriço ( lmc@di.fc.ul.pt ) added to authors
# 	Processing form for author  Luís Carriço ...added to forms. Add article  2010_0017
#
# Processing article ...  2010_0018 added to articles
# 	Processing author ...  Tiago Reis ( treis@lasige.di.fc.ul.pt ) already in authors
# 	Processing form for author  Tiago Reis ...already in forms. Add article  2010_0018
# 	Processing author ...  Luís Carriço ( lmc@di.fc.ul.pt  ) already in authors
# 	Processing form for author  Luís Carriço ...already in forms. Add article  2010_0018
# 	Processing author ...  Carlos Duarte ( cad@di.fc.ul.pt  ) already in authors
# 	Processing form for author  Carlos Duarte ...already in forms. Add article  2010_0018
#
# Processing article ...  2010_0020 added to articles
# 	Processing author ...  Duarte Teixeira ( duarte.teixeira@gmail.com  ) added to authors
# 	Processing form for author  Duarte Teixeira ...added to forms. Add article  2010_0020
# 	Processing author ...  Mário Rui Gomes ( mario.gomes@tagus.ist.utl.pt ) added to authors
# 	Processing form for author  Mário Rui Gomes ...added to forms. Add article  2010_0020
#
# Processing article ...  2010_0021 added to articles
# 	Processing author ...  Leonor Teixeira ( lteixeira@ua.pt ) added to authors
# 	Processing form for author  Leonor Teixeira ...added to forms. Add article  2010_0021
# 	Processing author ...  vasco Saavedra ( vsaavedra@ua.pt ) added to authors
# 	Processing form for author  vasco Saavedra ...added to forms. Add article  2010_0021
# 	Processing author ...  Carlos Ferreira ( carlosf@ua.pt ) already in authors
# 	Processing form for author  Carlos Ferreira ...added to forms. Add article  2010_0021
# 	Processing author ...  Beatriz Sousa Santos ( bss@ua.pt ) already in authors
# 	Processing form for author  Beatriz Sousa Santos ...already in forms. Add article  2010_0021
#
# Processing article ...  2010_0022 added to articles
# 	Processing author ...  João C. Silva ( jcsilva@ipca.pt ) added to authors
# 	Processing form for author  João C. Silva ...added to forms. Add article  2010_0022
# 	Processing author ...  Carlos E. Silva ( carlosebms@gmail.com ) added to authors
# 	Processing form for author  Carlos E. Silva ...added to forms. Add article  2010_0022
# 	Processing author ...  José C. Campos ( jose.campos@di.uminho.pt ) added to authors
# 	Processing form for author  José C. Campos ...added to forms. Add article  2010_0022
# 	Processing author ...  João A. Saraiva ( jas@di.uminho.pt ) added to authors
# 	Processing form for author  João A. Saraiva ...added to forms. Add article  2010_0022
#
# Processing article ...  2010_0023 added to articles
# 	Processing author ...  Daniela Fonte ( danielafonte@di.uminho.pt  ) added to authors
# 	Processing form for author  Daniela Fonte ...added to forms. Add article  2010_0023
# 	Processing author ...  Daniela Cruz ( danieladacruz@di.uminho.pt ) added to authors
# 	Processing form for author  Daniela Cruz ...added to forms. Add article  2010_0023
# 	Processing author ...  Pedro Rangel Henriques ( prh@di.uminho.pt ) added to authors
# 	Processing form for author  Pedro Rangel Henriques ...added to forms. Add article  2010_0023
# 	Processing author ...  Alda Lopes Gançarski ( alda.gancarski@it-sudparis.eu ) added to authors
# 	Processing form for author  Alda Lopes Gançarski ...added to forms. Add article  2010_0023
#
# Processing article ...  2010_0025 added to articles
# 	Processing author ...  Rui Nuno Almeida (  rnaao@iscte.pt ) added to authors
# 	Processing form for author  Rui Nuno Almeida ...added to forms. Add article  2010_0025
# 	Processing author ...  Miguel Sales Dias (  miguel.dias@microsoft.com   ) added to authors
# 	Processing form for author  Miguel Sales Dias ...added to forms. Add article  2010_0025
#
# Processing article ...  2010_0026 added to articles
# 	Processing author ...  Pedro Ribeiro ( pedroribeir@gmail.com  ) already in authors
# 	Processing form for author  Pedro Ribeiro ...already in forms. Add article  2010_0026
# 	Processing author ...  Tiago silva ( tmgsilva@gmail.com ) added to authors
# 	Processing form for author  Tiago silva ...added to forms. Add article  2010_0026
# 	Processing author ...  Rui José ( rui@dsi.uminho.pt ) added to authors
# 	Processing form for author  Rui José ...added to forms. Add article  2010_0026
#
# Processing article ...  2010_0027 added to articles
# 	Processing author ...  Emília Duarte ( emilia.duarte@iade.pt  ) added to authors
# 	Processing form for author  Emília Duarte ...added to forms. Add article  2010_0027
# 	Processing author ...  Júlia Teles ( jteles@fmh.utl.pt  ) added to authors
# 	Processing form for author  Júlia Teles ...added to forms. Add article  2010_0027
# 	Processing author ...  Luís Teixeira ( lmteixeira@fmh.utl.pt ) added to authors
# 	Processing form for author  Luís Teixeira ...added to forms. Add article  2010_0027
# 	Processing author ...  Francisco Rebelo ( frebelo@fmh.utl.pt ) added to authors
# 	Processing form for author  Francisco Rebelo ...added to forms. Add article  2010_0027
#
# Processing article ...  2010_0028 added to articles
# 	Processing author ...  José Luís Silva ( lsilva@di.uminho.pt ) added to authors
# 	Processing form for author  José Luís Silva ...added to forms. Add article  2010_0028
# 	Processing author ...  Oscar R. Ribeiro ( orribeiro@di.uminho.pt ) added to authors
# 	Processing form for author  Oscar R. Ribeiro ...added to forms. Add article  2010_0028
# 	Processing author ...  João M. Fernandes ( jmf@di.uminho.pt ) added to authors
# 	Processing form for author  João M. Fernandes ...added to forms. Add article  2010_0028
# 	Processing author ...  José Creissac Campos ( jose.campos@di.uminho.pt ) added to authors
# 	Processing form for author  José Creissac Campos ...added to forms. Add article  2010_0028
# 	Processing author ...  Michael D. Harrison ( michael.harrison@ncl.ac.uk ) added to authors
# 	Processing form for author  Michael D. Harrison ...added to forms. Add article  2010_0028
#
# Processing article ...  2010_0029 added to articles
# 	Processing author ...  Luís Bruno ( lbruno@ipbeja.pt ) added to authors
# 	Processing form for author  Luís Bruno ...added to forms. Add article  2010_0029
# 	Processing author ...  Bruno Araújo ( brar@vimmi.inesc-id.pt  ) already in authors
# 	Processing form for author  Bruno Araújo ...already in forms. Add article  2010_0029
# 	Processing author ...  João Pereira ( jap@inesc-id.pt ) added to authors
# 	Processing form for author  João Pereira ...added to forms. Add article  2010_0029
# 	Processing author ...  Joaquim Jorge (  jaj@inesc-id.pt  ) already in authors
# 	Processing form for author  Joaquim Jorge ...already in forms. Add article  2010_0029
#
# Processing article ...  2010_0030 added to articles
# 	Processing author ...  Paulo Dias ( paulo.diasj@ua.p ) already in authors
# 	Processing form for author  Paulo Dias ...already in forms. Add article  2010_0030
# 	Processing author ...  Paulo Santos ( a27638@alunos.det.ua. pt ) added to authors
# 	Processing form for author  Paulo Santos ...added to forms. Add article  2010_0030
# 	Processing author ...  Carlos Ferreira ( carlosf@ua.pt  ) already in authors
# 	Processing form for author  Carlos Ferreira ...already in forms. Add article  2010_0030
# 	Processing author ...  Beatriz Sousa Santos ( bss@ua.pt ) already in authors
# 	Processing form for author  Beatriz Sousa Santos ...already in forms. Add article  2010_0030
#
# Processing article ...  2010_0031 added to articles
# 	Processing author ...  Catarina Mendonça ( mendonca.catarina@gmail.com  ) added to authors
# 	Processing form for author  Catarina Mendonça ...added to forms. Add article  2010_0031
# 	Processing author ...  Jorge A. Santos ( jorge.a.santos@psi.uminho.pt  ) added to authors
# 	Processing form for author  Jorge A. Santos ...added to forms. Add article  2010_0031
# 	Processing author ...  Guilherme Campos ( guilherme.campos@ua.pt  ) added to authors
# 	Processing form for author  Guilherme Campos ...added to forms. Add article  2010_0031
# 	Processing author ...  Paulo Dias ( paulo.dias@ua.pt  ) already in authors
# 	Processing form for author  Paulo Dias ...already in forms. Add article  2010_0031
# 	Processing author ...  João P. Ferreira (  jpg.ferreira@gmail.com  ) added to authors
# 	Processing form for author  João P. Ferreira ...added to forms. Add article  2010_0031
#
# Processing article ...  2010_0033 added to articles
# 	Processing author ...  Paulo Gomes ( paulo.gomes@ist.utl.pt ) added to authors
# 	Processing form for author  Paulo Gomes ...added to forms. Add article  2010_0033
# 	Processing author ...  Sandra Gama (  sandra.gama@ist.utl.pt ) added to authors
# 	Processing form for author  Sandra Gama ...added to forms. Add article  2010_0033
# 	Processing author ...  Daniel Gonçalves ( daniel.goncalves@inesc-id.pt ) already in authors
# 	Processing form for author  Daniel Gonçalves ...already in forms. Add article  2010_0033
#
# Processing article ...  2010_0034 added to articles
# 	Processing author ...  João Teixeira ( joao.teixeira@ist.utl.pt ) added to authors
# 	Processing form for author  João Teixeira ...added to forms. Add article  2010_0034
# 	Processing author ...  Gabriel Barata ( gabriel.barata@ist.utl.pt ) added to authors
# 	Processing form for author  Gabriel Barata ...added to forms. Add article  2010_0034
# 	Processing author ...  Daniel Gonçalves ( daniel.goncalves@inesc-id.pt ) already in authors
# 	Processing form for author  Daniel Gonçalves ...already in forms. Add article  2010_0034
#
# Processing article ...  2010_0035 added to articles
# 	Processing author ...  Filipe Gil ( fgil@armail.pt  ) added to authors
# 	Processing form for author  Filipe Gil ...added to forms. Add article  2010_0035
# 	Processing author ...  Ana Paula Cláudio ( apc@di.fc.ul.pt ) already in authors
# 	Processing form for author  Ana Paula Cláudio ...already in forms. Add article  2010_0035
# 	Processing author ...  Maria Beatriz Carmo ( bc@di.fc.ul.pt ) already in authors
# 	Processing form for author  Maria Beatriz Carmo ...already in forms. Add article  2010_0035
#
# Processing article ...  2010_0036 added to articles
# 	Processing author ...  Gabriel Barata ( gabriel.barata@ist.utl.pt ) already in authors
# 	Processing form for author  Gabriel Barata ...already in forms. Add article  2010_0036
# 	Processing author ...  Ricardo Dias ( ricardo.dias@ist.utl.pt ) already in authors
# 	Processing form for author  Ricardo Dias ...already in forms. Add article  2010_0036
# 	Processing author ...  Sandra Gama ( sandra.gama@ist.utl.pt ) already in authors
# 	Processing form for author  Sandra Gama ...already in forms. Add article  2010_0036
# 	Processing author ...  Manuel J. Fonseca ( mjf@inesc-id.pt ) already in authors
# 	Processing form for author  Manuel J. Fonseca ...already in forms. Add article  2010_0036
# 	Processing author ...  Daniel Gonçalves ( daniel.goncalves@inesc-id.pt ) already in authors
# 	Processing form for author  Daniel Gonçalves ...already in forms. Add article  2010_0036
#
# Processing article ...  2010_0037 added to articles
# 	Processing author ...  Ricardo Dias ( ricardo.dias@ist.utl.pt ) already in authors
# 	Processing form for author  Ricardo Dias ...already in forms. Add article  2010_0037
# 	Processing author ...  Manuel J. Fonseca ( mjf@inesc-id.pt ) already in authors
# 	Processing form for author  Manuel J. Fonseca ...already in forms. Add article  2010_0037
#
# Processing article ...  2010_0039 added to articles
# 	Processing author ...  Fausto José Mourato ( fausto.mourato@estsetubal.ips.pt  ) added to authors
# 	Processing form for author  Fausto José Mourato ...added to forms. Add article  2010_0039
# 	Processing author ...  Manuel Própero Santos ( ps@di.fct.unl.pt ) added to authors
# 	Processing form for author  Manuel Própero Santos ...added to forms. Add article  2010_0039
#
# Processing article ...  2010_0040 added to articles
# 	Processing author ...  André F. S. Barbosa ( andrefsbarbosa@gmail.com  ) added to authors
# 	Processing form for author  André F. S. Barbosa ...added to forms. Add article  2010_0040
# 	Processing author ...  Frutuoso G. M. Silva ( fsilva@di.ubi.pt ) already in authors
# 	Processing form for author  Frutuoso G. M. Silva ...already in forms. Add article  2010_0040
#
# Processing article ...  2010_0041 added to articles
# 	Processing author ...  Luis F. A. Silva ( m2086@ubi.pt ) already in authors
# 	Processing form for author  Luis F. A. Silva ...added to forms. Add article  2010_0041
# 	Processing author ...  Frutuoso G. M. Silva ( fsilva@di.ubi.pt ) already in authors
# 	Processing form for author  Frutuoso G. M. Silva ...already in forms. Add article  2010_0041
#
# Processing article ...  2010_0042 added to articles
# 	Processing author ...  Bruno Miguel Cardoso ( b.m.pinto.cardoso@gmail.com  ) added to authors
# 	Processing form for author  Bruno Miguel Cardoso ...added to forms. Add article  2010_0042
# 	Processing author ...  Teresa Romão ( tir@di.fct.unl.pt  ) added to authors
# 	Processing form for author  Teresa Romão ...added to forms. Add article  2010_0042
#
# Processing article ...  2010_0043 added to articles
# 	Processing author ...  Rui Raposo ( raposo@ua.pt  ) added to authors
# 	Processing form for author  Rui Raposo ...added to forms. Add article  2010_0043
# 	Processing author ...  Nídia Salomé Morais ( salome@esev.ipv.pt  ) added to authors
# 	Processing form for author  Nídia Salomé Morais ...added to forms. Add article  2010_0043
#
# Processing article ...  2010_0045 added to articles
# 	Processing author ...  Luís Alexandre ( luis.alexandre@ipbeja.pt  ) added to authors
# 	Processing form for author  Luís Alexandre ...added to forms. Add article  2010_0045
# 	Processing author ...  Salvador Abreu ( spa@di.uevora.pt  ) added to authors
# 	Processing form for author  Salvador Abreu ...added to forms. Add article  2010_0045
#
# Processing article ...  2010_0046 added to articles
# 	Processing author ...  Sofia Pessanha ( sofia.pessanha@gmail.com  ) added to authors
# 	Processing form for author  Sofia Pessanha ...added to forms. Add article  2010_0046
# 	Processing author ...  Pedro Campos ( pedro.campos@inesc-id.pt ) added to authors
# 	Processing form for author  Pedro Campos ...added to forms. Add article  2010_0046
#
# Processing article ...  2010_0047 added to articles
# 	Processing author ...  Tiago Guerreiro ( tjvg@vimmi.inesc-id.pt ) added to authors
# 	Processing form for author  Tiago Guerreiro ...added to forms. Add article  2010_0047
# 	Processing author ...  Hugo Nicolau ( hman@vimmi.inesc-id.pt ) added to authors
# 	Processing form for author  Hugo Nicolau ...added to forms. Add article  2010_0047
# 	Processing author ...  Joaquim Jorge ( jaj@inesc-id.pt ) already in authors
# 	Processing form for author  Joaquim Jorge ...already in forms. Add article  2010_0047
# ...
# 	Processing form for author  Tiago Guerreiro ...already in forms. Add article  2008_0016
# 	Processing author ...  Daniel Gonçalves ( djvg@immi.inesc-id.pt ) already in authors
# 	Processing form for author  Daniel Gonçalves ...already in forms. Add article  2008_0016
#
# Processing article ...  2008_0017 added to articles
# 	Processing author ...  Mario M. Berón ( mberon@unsl.edu.ar ) added to authors
# 	Processing form for author  Mario M. Berón ...added to forms. Add article  2008_0017
# 	Processing author ...  Daniela Cruz ( danieladacruz@di.uminho.pt ) already in authors
# 	Processing form for author  Daniela Cruz ...already in forms. Add article  2008_0017
# 	Processing author ...  Maria João Varanda Pereira ( mjoao@ipb.pt ) added to authors
# 	Processing form for author  Maria João Varanda Pereira ...added to forms. Add article  2008_0017
# 	Processing author ...  Pedro Rangel Henriques ( pedrorangelhenriques@gmail.com ) already in authors
# 	Processing form for author  Pedro Rangel Henriques ...already in forms. Add article  2008_0017
# 	Processing author ...  Roberto Uzal ( ruzal@uolsinectis.com.ar ) added to authors
# 	Processing form for author  Roberto Uzal ...added to forms. Add article  2008_0017
#
# Processing article ...  2008_0018 added to articles
# 	Processing author ...  Teresa Romão ( tir@di.fct.unl.pt ) already in authors
# 	Processing form for author  Teresa Romão ...already in forms. Add article  2008_0018
# 	Processing author ...  Nuno Correia ( nmc@di.fct.unl.pt ) added to authors
# 	Processing form for author  Nuno Correia ...added to forms. Add article  2008_0018
# 	Processing author ...  Tiago Martins ( Tiago.Martins@ufg.ac.at ) added to authors
# 	Processing form for author  Tiago Martins ...added to forms. Add article  2008_0018
# 	Processing author ...  Christa Sommerer ( Christa.Sommerer@ufg.ac.at ) added to authors
# 	Processing form for author  Christa Sommerer ...added to forms. Add article  2008_0018
# 	Processing author ...  Laurent Mignonneau ( Laurent.Mignonneau@ufg.ac.at ) added to authors
# 	Processing form for author  Laurent Mignonneau ...added to forms. Add article  2008_0018
#
# Processing article ...  2008_0019 added to articles
# 	Processing author ...  Nuno Guerreiro ( pg10965@mail.uminho.pt ) added to authors
# 	Processing form for author  Nuno Guerreiro ...added to forms. Add article  2008_0019
# 	Processing author ...  Sandrine Mendes ( pg10968@mail.uminho.pt ) added to authors
# 	Processing form for author  Sandrine Mendes ...added to forms. Add article  2008_0019
# 	Processing author ...  Vítor Pinheiro ( pg11965@mail.uminho.pt ) added to authors
# 	Processing form for author  Vítor Pinheiro ...added to forms. Add article  2008_0019
# 	Processing author ...  José Creissac Campos ( jose.campos@di.uminho.pt  ) already in authors
# 	Processing form for author  José Creissac Campos ...already in forms. Add article  2008_0019
#
# Processing article ...  2008_0020 added to articles
# 	Processing author ...  Ana Cristina Ramada Paiva ( apaiva@fe.up.pt ) added to authors
# 	Processing form for author  Ana Cristina Ramada Paiva ...added to forms. Add article  2008_0020
# 	Processing author ...  Rodrigo M. L. M. Moreira ( ei04093@fe.up.pt ) added to authors
# 	Processing form for author  Rodrigo M. L. M. Moreira ...added to forms. Add article  2008_0020
#
# Processing article ...  2008_0021 added to articles
# 	Processing author ...  Bruno Miguel Cardoso ( b.m.pinto.cardoso@gmail.com  ) already in authors
# 	Processing form for author  Bruno Miguel Cardoso ...already in forms. Add article  2008_0021
# 	Processing author ...  Romão Teresa ( tir@di.fct.unl.pt  ) added to authors
# 	Processing form for author  Romão Teresa ...added to forms. Add article  2008_0021
#
# Processing article ...  2008_0022 added to articles
# 	Processing author ...  Marco Sá (  marcosa@di.fc.ul.pt  ) already in authors
# 	Processing form for author  Marco Sá ...already in forms. Add article  2008_0022
# 	Processing author ...  Luís Carriço ( lmc@di.fc.ul.pt ) already in authors
# 	Processing form for author  Luís Carriço ...already in forms. Add article  2008_0022
#
# Processing article ...  2008_0023 added to articles
# 	Processing author ...  Patrícia Bastos ( pat.bastos0011@sapo.pt ) added to authors
# 	Processing form for author  Patrícia Bastos ...added to forms. Add article  2008_0023
# 	Processing author ...  Miguel Sales Dias ( miguel.dias@microsoft.com  ) already in authors
# 	Processing form for author  Miguel Sales Dias ...already in forms. Add article  2008_0023
#
# Processing article ...  2008_0024 added to articles
# 	Processing author ...  Samuel Silva ( sss@ua.pt ) already in authors
# 	Processing form for author  Samuel Silva ...already in forms. Add article  2008_0024
# 	Processing author ...  Paulo Dias (  paulo.dias@ua.pt ) already in authors
# 	Processing form for author  Paulo Dias ...already in forms. Add article  2008_0024
# 	Processing author ...  Beatriz Sousa Santos ( bss@ua.pt ) already in authors
# 	Processing form for author  Beatriz Sousa Santos ...already in forms. Add article  2008_0024
# 	Processing author ...  Carlos Ferreira ( carlosf@ua.pt ) already in authors
# 	Processing form for author  Carlos Ferreira ...already in forms. Add article  2008_0024
#
# Processing article ...  2008_0025 added to articles
# 	Processing author ...  Ricardo Casaleiro (  a26197@ua.pt ) added to authors
# 	Processing form for author  Ricardo Casaleiro ...added to forms. Add article  2008_0025
# 	Processing author ...  Paulo Dias (  paulo.dias@ua.pt ) already in authors
# 	Processing form for author  Paulo Dias ...already in forms. Add article  2008_0025
# 	Processing author ...  Guilherme campos ( agrcampos@ua.pt ) added to authors
# 	Processing form for author  Guilherme campos ...added to forms. Add article  2008_0025
# 	Processing author ...  Beatriz Sousa Santos ( bss@ua.pt ) already in authors
# 	Processing form for author  Beatriz Sousa Santos ...already in forms. Add article  2008_0025
#
# Processing article ...  2008_0026 added to articles
# 	Processing author ...  Paulo Ricca ( paulo.goncalves@ipvc.pt ) added to authors
# 	Processing form for author  Paulo Ricca ...added to forms. Add article  2008_0026
# 	Processing author ...  Rui Braga ( rbraga@ipvc.pt  ) added to authors
# 	Processing form for author  Rui Braga ...added to forms. Add article  2008_0026
# 	Processing author ...  Marta Boas ( mboas@ipvc.pt  ) added to authors
# 	Processing form for author  Marta Boas ...added to forms. Add article  2008_0026
# 	Processing author ...  Vasco Duarte ( vduarte@ipvc.pt  ) added to authors
# 	Processing form for author  Vasco Duarte ...added to forms. Add article  2008_0026
# 	Processing author ...  Marco Sousa ( marcosousa@ipvc.pt  ) added to authors
# 	Processing form for author  Marco Sousa ...added to forms. Add article  2008_0026
# 	Processing author ...  João Coelho ( jcoelho@ipvc.pt  ) added to authors
# 	Processing form for author  João Coelho ...added to forms. Add article  2008_0026
# 	Processing author ...  Luís Romero ( romero@estg.ipvc.pt ) added to authors
# 	Processing form for author  Luís Romero ...added to forms. Add article  2008_0026
#
# Processing article ...  2008_0027 added to articles
# 	Processing author ...  Sérgio Oliveira ( sergio.oliveira@pt.ibm.com ) added to authors
# 	Processing form for author  Sérgio Oliveira ...added to forms. Add article  2008_0027
# 	Processing author ...  Rui José ( rui@dsi.uminho.pt ) already in authors
# 	Processing form for author  Rui José ...already in forms. Add article  2008_0027
#
# Processing article ...  2008_0028 added to articles
# 	Processing author ...  Nuno Otero ( nuno.otero@dsi.uminho.pt ) added to authors
# 	Processing form for author  Nuno Otero ...added to forms. Add article  2008_0028
# 	Processing author ...  Rui José ( rui@dsi.uminho.pt ) already in authors
# 	Processing form for author  Rui José ...already in forms. Add article  2008_0028
#
# Processing article ...  2008_0029 added to articles
# 	Processing author ...  Ana F. Vaz ( afvaz@lasige.di.fc.ul.pt ) added to authors
# 	Processing form for author  Ana F. Vaz ...added to forms. Add article  2008_0029
# 	Processing author ...  Paulo P. Matos (  ppombinho@lasige.di.fc.ul.pt ) added to authors
# 	Processing form for author  Paulo P. Matos ...added to forms. Add article  2008_0029
# 	Processing author ...  Ana Paula Afonso ( apa@di.fc.ul.pt ) already in authors
# 	Processing form for author  Ana Paula Afonso ...already in forms. Add article  2008_0029
# 	Processing author ...  Maria Beatriz Carmo ( bc@di.fc.ul.pt ) already in authors
# 	Processing form for author  Maria Beatriz Carmo ...already in forms. Add article  2008_0029
#
# Processing article ...  2008_0030 added to articles
# 	Processing author ...  Leonel Câmara ( leonelcamara@gmail.com ) added to authors
# 	Processing form for author  Leonel Câmara ...added to forms. Add article  2008_0030
# 	Processing author ...  Tiago Guerreiro ( tjvg@immi.inesc-id.pt ) already in authors
# 	Processing form for author  Tiago Guerreiro ...already in forms. Add article  2008_0030
# 	Processing author ...  Daniel Gonçalves ( djvg@immi.inesc-id.pt ) already in authors
# 	Processing form for author  Daniel Gonçalves ...already in forms. Add article  2008_0030
#
# Processing article ...  2008_0031 added to articles
# 	Processing author ...  Miguel Borges ( borges.miguel@gmail.com ) added to authors
# 	Processing form for author  Miguel Borges ...added to forms. Add article  2008_0031
# 	Processing author ...  José Creissac Campos ( jose.campos@di.uminho.pt ) already in authors
# 	Processing form for author  José Creissac Campos ...already in forms. Add article  2008_0031
# 	Processing author ...  António Nestor Ribeiro ( anr@di.uminho.pt ) added to authors
# 	Processing form for author  António Nestor Ribeiro ...added to forms. Add article  2008_0031
#
# Processing article ...  2008_0032 added to articles
# 	Processing author ...  Carlos Urbano ( curbano@estg.ipleiria.pt ) already in authors
# 	Processing form for author  Carlos Urbano ...already in forms. Add article  2008_0032
# 	Processing author ...  Luís Magalhães ( lmagalha@utad.pt  ) already in authors
# 	Processing form for author  Luís Magalhães ...already in forms. Add article  2008_0032
# 	Processing author ...  João Paulo Moura ( jpmoura@utad.pt ) already in authors
# 	Processing form for author  João Paulo Moura ...already in forms. Add article  2008_0032
# 	Processing author ...  Adérito Fernandes Marcos ( marcos@dsi.uminho.pt ) already in authors
# 	Processing form for author  Adérito Fernandes Marcos ...already in forms. Add article  2008_0032
#
# Processing article ...  2008_0033 added to articles
# 	Processing author ...  Paulo Lagoa ( plagoa@netcabo.pt ) added to authors
# 	Processing form for author  Paulo Lagoa ...added to forms. Add article  2008_0033
# 	Processing author ...  Hugo Nicolau ( h.nicolau@gmail.com ) already in authors
# 	Processing form for author  Hugo Nicolau ...already in forms. Add article  2008_0033
# 	Processing author ...  Tiago Guerreiro ( tjvg@immi.inesc.pt ) already in authors
# 	Processing form for author  Tiago Guerreiro ...already in forms. Add article  2008_0033
# 	Processing author ...  Daniel Gonçalves ( djvg@immi.inesc.pt ) already in authors
# 	Processing form for author  Daniel Gonçalves ...already in forms. Add article  2008_0033
# 	Processing author ...  Joaquim Jorge ( jaj@acm.org ) already in authors
# 	Processing form for author  Joaquim Jorge ...already in forms. Add article  2008_0033
#
# Processing article ...  2008_0034 added to articles
# 	Processing author ...  Rui Lopes ( rlopes@di.fc.ul.pt ) already in authors
# 	Processing form for author  Rui Lopes ...already in forms. Add article  2008_0034
# 	Processing author ...  Luís Carriço ( lmc@di.fc.ul.pt ) already in authors
# 	Processing form for author  Luís Carriço ...already in forms. Add article  2008_0034
#
# Processing article ...  2008_0035 added to articles
# 	Processing author ...  Luís Bruno ( lbruno@estig.ipbeja.pt  ) already in authors
# 	Processing form for author  Luís Bruno ...already in forms. Add article  2008_0035
# 	Processing author ...  Joaquina Carreteiro (  maria.carreteiro@estig.ipbeja.pt  ) added to authors
# 	Processing form for author  Joaquina Carreteiro ...added to forms. Add article  2008_0035
# 	Processing author ...  Hugo Gonçalves (  hugo.goncalves@estig.ipbeja.pt  ) added to authors
# 	Processing form for author  Hugo Gonçalves ...added to forms. Add article  2008_0035
# 	Processing author ...  Luís Garcia ( luisbgarcia@estig.ipbeja.pt  ) added to authors
# 	Processing form for author  Luís Garcia ...added to forms. Add article  2008_0035
#
# Processing article ...  2008_0036 added to articles
# 	Processing author ...  Luís Garcia ( luisbgarcia@estig.ipbeja.pt  ) already in authors
# 	Processing form for author  Luís Garcia ...already in forms. Add article  2008_0036
# 	Processing author ...  Luís Oliveira ( lco@inesc-id.pt  ) added to authors
# 	Processing form for author  Luís Oliveira ...added to forms. Add article  2008_0036
#
# Processing article ...  2008_0037 added to articles
# 	Processing author ...  Cristina Sylla ( csylla@ilch.uminho.pt  ) added to authors
# 	Processing form for author  Cristina Sylla ...added to forms. Add article  2008_0037
# 	Processing author ...  Pedro Branco ( pbranco@dsi.uminho.pt ) already in authors
# 	Processing form for author  Pedro Branco ...already in forms. Add article  2008_0037
#
# Processing article ...  2008_0038 added to articles
# 	Processing author ...  Ana Cristino ( netbairros@gmail.com ) added to authors
# 	Processing form for author  Ana Cristino ...added to forms. Add article  2008_0038
# 	Processing author ...  Diogo Silva (  ) added to authors
# 	Processing author ...  Maria João Maia (  ) added to authors
# 	Processing author ...  Tiago Moreira (  ) added to authors
# 	Processing author ...  Ana Carla Amaro (  ) added to authors
# 	Processing author ...  Maria João Antunes (  ) added to authors
#
# Processing article ...  2008_0039 added to articles
# 	Processing author ...  Ricardo Abreu Lopes ( rval@ist.utl.pt ) added to authors
# 	Processing form for author  Ricardo Abreu Lopes ...added to forms. Add article  2008_0039
# 	Processing author ...  Manuel J. Fonseca ( mjf@inesc-id.pt ) already in authors
# 	Processing form for author  Manuel J. Fonseca ...already in forms. Add article  2008_0039
#
# Processing article ...  2008_0040 added to articles
# 	Processing author ...  Duarte Gonçalves ( dnjg@di.fct.unl.pt ) added to authors
# 	Processing form for author  Duarte Gonçalves ...added to forms. Add article  2008_0040
# 	Processing author ...  Rui Jesus ( rjesus@deetc.isel.ipl.pt ) added to authors
# 	Processing form for author  Rui Jesus ...added to forms. Add article  2008_0040
# 	Processing author ...  Filipe Grangeiro ( isel.ipl.pt ) added to authors
# 	Processing author ...  Nuno Correia ( nmc@di.fct.unl.pt ) already in authors
# 	Processing form for author  Nuno Correia ...already in forms. Add article  2008_0040
#
# Processing article ...  2008_0041 added to articles
# 	Processing author ...  Tiago Trindade ( tiago.trindade@ist.utl.pt ) added to authors
# 	Processing form for author  Tiago Trindade ...added to forms. Add article  2008_0041
# 	Processing author ...  Tiago Guerreiro ( tjvg@immi.inesc-id.p ) already in authors
# 	Processing form for author  Tiago Guerreiro ...already in forms. Add article  2008_0041
# 	Processing author ...  Joaquim A. Jorge ( jorgej@acm.org ) already in authors
# 	Processing form for author  Joaquim A. Jorge ...already in forms. Add article  2008_0041
#
# Processing article ...  2008_0042 added to articles
# 	Processing author ...  David M. Graça ( david.graca@ist.utl.pt ) added to authors
# 	Processing form for author  David M. Graça ...added to forms. Add article  2008_0042
# 	Processing author ...  Tiago Guerreiro (  tjvg@immi.inesc.pt ) already in authors
# 	Processing form for author  Tiago Guerreiro ...already in forms. Add article  2008_0042
# 	Processing author ...  Joaquim A. Jorge ( jorgej@acm.org ) already in authors
# 	Processing form for author  Joaquim A. Jorge ...already in forms. Add article  2008_0042
#
# *** Finished file 2008Interacao ***

# %%
# pickle dump the data structures

if events_modified:
    with open(pkl_path+events_fn,"wb") as events_out:
        pickle.dump(events, events_out)

if articles_modified:
    with open(pkl_path+articles_fn,"wb") as articles_out:
        pickle.dump(articles, articles_out)
        
if authors_modified:
    with open(pkl_path+authors_fn,"wb") as authors_out:
        pickle.dump(authors, authors_out)

if art_aut_modified:
    with open(pkl_path+art_aut_fn,"wb") as art_aut_out:
        pickle.dump(art_aut, art_aut_out)

if forms_modified:
    with open(pkl_path+forms_fn,"wb") as forms_out:
        pickle.dump(forms, forms_out)

# %%
print ('That\'s all, folks')
# Out:
# That's all, folks
