# %%
import csv
import pickle
import re  # string processing

# %%
# csv files
csv_path = 'csv\\'

csv_files = ['2003EPCG','2004Interacao','2005EPCG','2006Interacao','2007EPCG']
#csv_files = ['2008Interacao']
csv_extension = '.csv'

# %%
# pkl files and data structures
pkl_path = 'pkl\\'

# load the events data structure (if it exists)
events_fn = 'events.pkl'
events_modified = False

# verify if the file exists
try:
    with open(pkl_path+events_fn,"rb") as events_in:
        events = pickle.load(events_in)
except FileNotFoundError:
    events = []
print ('There are {0} events!'.format(len(events)))
#print (events)

# load the articles data structure (if it exists)
articles_fn = 'articles.pkl'
articles_modified = False

# verify if the file exists
try:
    with open(pkl_path+articles_fn,"rb") as articles_in:
        articles = pickle.load(articles_in)
except FileNotFoundError:
    articles = []
print ('There are {0} articles!'.format(len(articles)))
#print (articles)

# load the authors data structure (if it exists)
authors_fn = 'authors.pkl'
authors_modified = False

# verify if the file exists
try:
    with open(pkl_path+authors_fn,"rb") as authors_in:
        authors = pickle.load(authors_in)
except FileNotFoundError:
    authors = []
print ('There are {0} authors!'.format(len(authors)))
#print (authors)

# load the articles/authors data structure (if it exists)
art_aut_fn = 'art_aut.pkl'
art_aut_modified = False

# verify if the file exists
try:
    with open(pkl_path+art_aut_fn,"rb") as art_aut_in:
        art_aut = pickle.load(art_aut_in)
except FileNotFoundError:
    art_aut = []
print ('There are {0} articles-authors relationships!'.format(len(art_aut)))
#print (art_aut)

# load the forms data structure (if it exists)
forms_fn = 'forms.pkl'
forms_modified = False

# verify if the file exists
try:
    with open(pkl_path+forms_fn,"rb") as forms_in:
        forms = pickle.load(forms_in)
except FileNotFoundError:
    forms = []
print ('There are {0} forms!'.format(len(forms)))
#print (art_aut)
# Out:
# There are 0 events!
# There are 0 articles!
# There are 0 authors!
# There are 0 articles-authors relationships!
# There are 0 forms!

# %%
import time
import random
import hashlib
import unicodedata

# Use this function to generate a unique ID for each author
# use name as arg to generate more randomness

def guid( arg ):
    """
    Generates a universally unique ID.
    Any arguments only create more randomness.
    """
    t = int( time.time() * 1000 )
    r = int( random.random()*10000000 )
    data = str(t)+' '+str(r)+' '+arg
    data = unicodedata.normalize('NFKD', data).encode('ascii', 'ignore')
    #print (data, flush=True)
    data = hashlib.md5(data).hexdigest()

    return data

# %%
# main loop
for csv_file in csv_files:
    print ('*** Processing file {0} ***'.format(csv_file))
    
    csv_fileN = csv_path + csv_file + csv_extension    
    # read the csv file
    try:
        with open(csv_fileN,'rt') as csv_in:
            
            # Loop remaining rows
            for rownum, row in enumerate(csv.reader(csv_in, delimiter=";")):

                # for the first row get indexes of the required fields
                if rownum==0:
                    # event
                    Acronym_col = row.index ('Acronym')
                    Year_col = row.index ('Year')
                    Event_col = row.index ('Event')
                    # article
                    Type_col = row.index ('Type')
                    Title_col = row.index ('Title')
                    File_col = row.index ('File')
                    ArticleKey_col = row.index ('ArticleKey')
                    # authors col indexes
                    authors_col = []
                    au_n = 1
                    finish = False
                    while not finish:
                        LN = 'Author' + str(au_n) + 'LastName'
                        FN = 'Author' + str(au_n) + 'FirstName'
                        Contact = 'Author' + str(au_n) + 'Contact'
                        try:
                            LN_col = row.index (LN)
                            FN_col = row.index (FN)
                            contact_col = row.index (Contact)
                            authors_col.append((LN_col, FN_col, contact_col))
                            au_n += 1
                        except ValueError:
                            finish = True
                    continue
            
                # for the first data row verify the event
                if rownum==1:
                    Acronym = row[Acronym_col]
                    # verify if this event already exists in the events data structure
                    event_exists = False
                    for event in events:
                        if event['acr']==Acronym:
                            event_exists = True
                            break
                    if not event_exists:  # append event to events
                        event_dict = {'acr':Acronym, 'name':row[Event_col],
                                      'year':row[Year_col], 'state': 'loaded'}
                        events.append(event_dict)
                        events_modified = True
                        
                # for the current row (article)
                if row[Type_col]!='Article':
                    continue
                # article data
                ArticleKey = row[ArticleKey_col]
                print ("Processing article ... ", ArticleKey, end = ' ')
                # verify if this article already exists in the articles data structure
                article_exists = False
                for article in articles:
                    if article['ID']==ArticleKey:
                        article_exists = True
                        break
                if not article_exists:  # append event to articles
                    Acronym = row[Acronym_col]
                    Title = row[Title_col]
                    File = row[File_col]
                    art_dict = {'ID':ArticleKey, 'event':Acronym,
                           'title':Title, 'file':File, 'state':'loaded'}
                    articles.append(art_dict)
                    articles_modified = True
                    print ("added to articles")
                else:
                    print ("already in articles")
                # authors data
                this_authors = []
                for au in authors_col:
                    LN_col = au[0]
                    FN_col = au[1]
                    contact_col = au[2]
                    if row[LN_col]=="": break  # last author was previous
                    LN = row[LN_col]
                    LN = LN.strip()
                    LN = re.sub("\s\s+", " ", LN)
                    FN = row[FN_col]
                    FN = FN.strip()
                    FN = re.sub("\s\s+", " ", FN)
                    Name = FN+' '+LN
                    this_authors.append((Name,row[contact_col]))

                for aut in this_authors:                
                    AuthorName = aut[0]
                    AuthorContact = aut[1]
                    print ("\tProcessing author ... ", AuthorName, '(', AuthorContact,')', end = ' ')
                    # verify if this author already exists in the authors data structure
                    author_exists = False
                    for author in authors:
                        if author['name']==AuthorName:
                            author_exists = True
                            AuthorKey = author['ID']
                            print ("already in authors")
                            break
                    if not author_exists:  # append author to authors
                        AuthorKey = guid (AuthorName)
                        aut_dict = {'ID':AuthorKey, 'name':AuthorName,
                                   'email':AuthorContact, 'state':'loaded'}
                        authors.append(aut_dict)
                        authors_modified = True
                        print ("added to authors")
                    
                    # add to the art_aut table
                    # firstly check whether it already exists
                    art_aut_exists = False
                    for this_art_aut in art_aut:
                        if this_art_aut[0]==ArticleKey and this_art_aut[1]==AuthorKey:
                            art_aut_exists = True
                            break
                    if not art_aut_exists:  # add
                        art_aut.append((ArticleKey,AuthorKey))
                        art_aut_modified = True

                    # Forms
                    # there will only be a form for the current author
                    # if its email exists
                    if (AuthorContact.find('@') != -1):
                        # verify whether there is already a form for this author
                        form_exists = False
                        print ("\tProcessing form for author ", AuthorName, end = ' ...')
                        for form in forms:
                            if form['ID']==AuthorKey:
                                form_exists=True
                                form['articles'].append(ArticleKey)
                                forms_modified = True
                                print ("already in forms. Add article ", ArticleKey)
                        if not form_exists:
                            form_dict = {'ID':AuthorKey, 'articles':[ArticleKey],
                                        'file':AuthorName+'-form.pdf',
                                        'state':'loaded'}
                            forms.append(form_dict)
                            forms_modified = True
                            print ("added to forms. Add article ", ArticleKey)
                # end authors loop 
                print ()
                    
            # end loop through csv rows
        # end opening csv_in
    except FileNotFoundError:
        print ('File {0} not found!'.format(csv_fileN))
        continue
        
    print ('*** Finished file {0} ***\n'.format(csv_file))
    # end loop through csv files
# Out:
# *** Processing file 2003EPCG ***
# Processing article ...  2003_0006 added to articles
# 	Processing author ...  Frutuoso G. M. Silva ( fsilva@di.ubi.pt  ) added to authors
# 	Processing form for author  Frutuoso G. M. Silva ...added to forms. Add article  2003_0006
# 	Processing author ...  Abel J. P. Gomes ( agomes@di.ubi.pt ) added to authors
# 	Processing form for author  Abel J. P. Gomes ...added to forms. Add article  2003_0006
#
# Processing article ...  2003_0007 added to articles
# 	Processing author ...  Francisco Morgado ( fmorgado@di.estv.ipv.pt ) added to authors
# 	Processing form for author  Francisco Morgado ...added to forms. Add article  2003_0007
# 	Processing author ...  Abel Gomes ( agomes@di.ubi.pt ) added to authors
# 	Processing form for author  Abel Gomes ...added to forms. Add article  2003_0007
#
# Processing article ...  2003_0008 added to articles
# 	Processing author ...  Bruno Rodrigues Araújo ( brar@immi.inesc.pt ) added to authors
# 	Processing form for author  Bruno Rodrigues Araújo ...added to forms. Add article  2003_0008
# 	Processing author ...  Joaquim Armando Pires Jorge ( jorgej@acm.org  ) added to authors
# 	Processing form for author  Joaquim Armando Pires Jorge ...added to forms. Add article  2003_0008
#
# Processing article ...  2003_0009 added to articles
# 	Processing author ...  Rafael Bidarra ( R.Bidarra@its.tudelft.nl ) added to authors
# 	Processing form for author  Rafael Bidarra ...added to forms. Add article  2003_0009
# 	Processing author ...  André van Bunnik (  ) added to authors
# 	Processing author ...  Willem F. Bronsvoort ( W.F.Bronsvoort)@its.tudelft.nl ) added to authors
# 	Processing form for author  Willem F. Bronsvoort ...added to forms. Add article  2003_0009
#
# Processing article ...  2003_0011 added to articles
# 	Processing author ...  Sofia Gameiro ( sofia.gameiro@coimbra.ccg.pt  ) added to authors
# 	Processing form for author  Sofia Gameiro ...added to forms. Add article  2003_0011
# 	Processing author ...  Luís Almeida (  Luis.Almeida}@coimbra.ccg.pt  ) added to authors
# 	Processing form for author  Luís Almeida ...added to forms. Add article  2003_0011
# 	Processing author ...  Adérito Marcos ( marcos@dsi.uminho.pt  ) added to authors
# 	Processing form for author  Adérito Marcos ...added to forms. Add article  2003_0011
#
# Processing article ...  2003_0012 added to articles
# 	Processing author ...  Pedro Faria Lopes ( Pedro.Lopes@iscte.pt ) added to authors
# 	Processing form for author  Pedro Faria Lopes ...added to forms. Add article  2003_0012
# 	Processing author ...  Maria Vasconcelos Moreira ( Maria.Moreira@iscte.pt ) added to authors
# 	Processing form for author  Maria Vasconcelos Moreira ...added to forms. Add article  2003_0012
# 	Processing author ...  Noel Santos ( Noel.Santos@iscte.pt ) added to authors
# 	Processing form for author  Noel Santos ...added to forms. Add article  2003_0012
#
# Processing article ...  2003_0013 added to articles
# 	Processing author ...  Fernando Pedro Birra ( fpb@di.fct.unl.pt  ) added to authors
# 	Processing form for author  Fernando Pedro Birra ...added to forms. Add article  2003_0013
# 	Processing author ...  Manuel Próspero Santos ( ps@di.fct.unl.pt  ) added to authors
# 	Processing form for author  Manuel Próspero Santos ...added to forms. Add article  2003_0013
#
# Processing article ...  2003_0015 added to articles
# 	Processing author ...  Paulo Bernardes ( pbernardes@uaum.uminho.pt ) added to authors
# 	Processing form for author  Paulo Bernardes ...added to forms. Add article  2003_0015
# 	Processing author ...  Manuela Martins ( mmmartins@uaum.uminho.pt ) added to authors
# 	Processing form for author  Manuela Martins ...added to forms. Add article  2003_0015
#
# Processing article ...  2003_0016 added to articles
# 	Processing author ...  António Fernando Coelho ( acoelho@utad.pt ) added to authors
# 	Processing form for author  António Fernando Coelho ...added to forms. Add article  2003_0016
# 	Processing author ...  António Augusto Sousa (  aas@fe.up.pt ) added to authors
# 	Processing form for author  António Augusto Sousa ...added to forms. Add article  2003_0016
# 	Processing author ...  Fernando Nunes Ferreira ( fnf@fe.up.pt ) added to authors
# 	Processing form for author  Fernando Nunes Ferreira ...added to forms. Add article  2003_0016
#
# Processing article ...  2003_0017 added to articles
# 	Processing author ...  Rodrigo Garcia ( rjsdg@mega.ist.utl.pt ) added to authors
# 	Processing form for author  Rodrigo Garcia ...added to forms. Add article  2003_0017
# 	Processing author ...  Mauro Farracha ( mdfa@mega.ist.utl.pt ) added to authors
# 	Processing form for author  Mauro Farracha ...added to forms. Add article  2003_0017
# 	Processing author ...  José Dionísio ( jdionisio@ist.utl.pt ) added to authors
# 	Processing form for author  José Dionísio ...added to forms. Add article  2003_0017
# 	Processing author ...  Alexandre Bernardino ( alex@isr.ist.utl.pt ) added to authors
# 	Processing form for author  Alexandre Bernardino ...added to forms. Add article  2003_0017
# 	Processing author ...  João Paulo Costeira ( jpc@isr.ist.utl.pt ) added to authors
# 	Processing form for author  João Paulo Costeira ...added to forms. Add article  2003_0017
#
# Processing article ...  2003_0018 added to articles
# 	Processing author ...  Alexandrino Gonçalves ( alex@estg.ipleiria.pt ) added to authors
# 	Processing form for author  Alexandrino Gonçalves ...added to forms. Add article  2003_0018
# 	Processing author ...  António José Mendes ( toze@dei.uc.pt ) added to authors
# 	Processing form for author  António José Mendes ...added to forms. Add article  2003_0018
#
# Processing article ...  2003_0020 added to articles
# 	Processing author ...  José Braz Pereira ( jbraz@est.ips.pt ) added to authors
# 	Processing form for author  José Braz Pereira ...added to forms. Add article  2003_0020
# 	Processing author ...  João Madeiras Pereira ( jap@inesc.pt  ) added to authors
# 	Processing form for author  João Madeiras Pereira ...added to forms. Add article  2003_0020
# 	Processing author ...  António Prieto Veloso ( apveloso@fmh.utl.pt  ) added to authors
# 	Processing form for author  António Prieto Veloso ...added to forms. Add article  2003_0020
#
# Processing article ...  2003_0021 added to articles
# 	Processing author ...  José Miguel Salles Dias ( Miguel.Dias@iscte.pt ) added to authors
# 	Processing form for author  José Miguel Salles Dias ...added to forms. Add article  2003_0021
# 	Processing author ...  Pedro Nande ( Pedro.Nande@iscte.pt ) added to authors
# 	Processing form for author  Pedro Nande ...added to forms. Add article  2003_0021
# 	Processing author ...  Pedro Santos ( Pedro.Santos@iscte.pt ) added to authors
# 	Processing form for author  Pedro Santos ...added to forms. Add article  2003_0021
# 	Processing author ...  Nuno Barata ( Nuno.Barata@iscte.pt ) added to authors
# 	Processing form for author  Nuno Barata ...added to forms. Add article  2003_0021
# 	Processing author ...  André Correia ( Andre.Correia@iscte.pt ) added to authors
# 	Processing form for author  André Correia ...added to forms. Add article  2003_0021
#
# Processing article ...  2003_0022 added to articles
# 	Processing author ...  Pedro Pereira ( Pedro.Pereira@ccg.pt  ) added to authors
# 	Processing form for author  Pedro Pereira ...added to forms. Add article  2003_0022
# 	Processing author ...  Nuno Matos ( Nuno.Matos@ccg.pt  ) added to authors
# 	Processing form for author  Nuno Matos ...added to forms. Add article  2003_0022
# 	Processing author ...  Luís Grave ( Luis.Grave@ccg.pt  ) added to authors
# 	Processing form for author  Luís Grave ...added to forms. Add article  2003_0022
# 	Processing author ...  Adérito Marcos ( marcos@dsi.uminho.pt  ) already in authors
# 	Processing form for author  Adérito Marcos ...already in forms. Add article  2003_0022
#
# Processing article ...  2003_0024 added to articles
# 	Processing author ...  A. Zita Sampaio ( zita@civil.ist.utl.pt  ) added to authors
# 	Processing form for author  A. Zita Sampaio ...added to forms. Add article  2003_0024
# 	Processing author ...  P. Gameiro Henriques ( pgameiro@civil.ist.utl.pt ) added to authors
# 	Processing form for author  P. Gameiro Henriques ...added to forms. Add article  2003_0024
#
# Processing article ...  2003_0025 added to articles
# 	Processing author ...  Vítor Cunha ( vmc@dee.isep.ipp.pt ) added to authors
# 	Processing form for author  Vítor Cunha ...added to forms. Add article  2003_0025
# 	Processing author ...  Miguel Leitão ( jml@dee.isep.ipp.pt ) added to authors
# 	Processing form for author  Miguel Leitão ...added to forms. Add article  2003_0025
#
# Processing article ...  2003_0026 added to articles
# 	Processing author ...  Pedro Leão Neto ( pleao@arq.up.pt  ) added to authors
# 	Processing form for author  Pedro Leão Neto ...added to forms. Add article  2003_0026
#
# Processing article ...  2003_0027 added to articles
# 	Processing author ...  Carlos Campos ( ccampos@ipp.pt  ) added to authors
# 	Processing form for author  Carlos Campos ...added to forms. Add article  2003_0027
# 	Processing author ...  Vítor Cunha ( vmc@dee.isep.ipp.pt  ) already in authors
# 	Processing form for author  Vítor Cunha ...already in forms. Add article  2003_0027
# 	Processing author ...  J. Miguel Leitão ( jml@dee.isep.ipp.pt  ) added to authors
# 	Processing form for author  J. Miguel Leitão ...added to forms. Add article  2003_0027
#
# Processing article ...  2003_0028 added to articles
# 	Processing author ...  Pedro Miguel Coelho ( pmc@mega.ist.utl.pt  ) added to authors
# 	Processing form for author  Pedro Miguel Coelho ...added to forms. Add article  2003_0028
# 	Processing author ...  Gonçalo França Faria ( gfs@mega.ist.utl.pt  ) added to authors
# 	Processing form for author  Gonçalo França Faria ...added to forms. Add article  2003_0028
# 	Processing author ...  Daniel Gonçalves ( djvg@gia.ist.utl.pt ) added to authors
# 	Processing form for author  Daniel Gonçalves ...added to forms. Add article  2003_0028
# 	Processing author ...  Joaquim A Jorge (  jorgej@acm.org  ) added to authors
# 	Processing form for author  Joaquim A Jorge ...added to forms. Add article  2003_0028
#
# Processing article ...  2003_0029 added to articles
# 	Processing author ...  Filipe Marques Dias ( fil@immi.inesc-id.pt ) added to authors
# 	Processing form for author  Filipe Marques Dias ...added to forms. Add article  2003_0029
# 	Processing author ...  Manuel J Fonseca ( mjf@inesc-id.pt ) added to authors
# 	Processing form for author  Manuel J Fonseca ...added to forms. Add article  2003_0029
# 	Processing author ...  Joaquim A Jorge ( jorgej@acm.org  ) already in authors
# 	Processing form for author  Joaquim A Jorge ...already in forms. Add article  2003_0029
#
# Processing article ...  2003_0030 added to articles
# 	Processing author ...  Alfredo Ferreira Jr. ( alfredo.ferreira.jr@inesc-id.pt ) added to authors
# 	Processing form for author  Alfredo Ferreira Jr. ...added to forms. Add article  2003_0030
# 	Processing author ...  Manuel J Fonseca ( mjf@inesc-id.pt ) already in authors
# 	Processing form for author  Manuel J Fonseca ...already in forms. Add article  2003_0030
# 	Processing author ...  Joaquim A Jorge ( jorgej@acm.org  ) already in authors
# 	Processing form for author  Joaquim A Jorge ...already in forms. Add article  2003_0030
#
# Processing article ...  2003_0031 added to articles
# 	Processing author ...  Samuel Silva ( a19775@alunos.det.ua.pt ) added to authors
# 	Processing form for author  Samuel Silva ...added to forms. Add article  2003_0031
# 	Processing author ...  Filipe Marques ( a20094@alunos.det.ua.pt ) added to authors
# 	Processing form for author  Filipe Marques ...added to forms. Add article  2003_0031
# 	Processing author ...  Manuel Raposo (  mraposo@oninet.pt ) added to authors
# 	Processing form for author  Manuel Raposo ...added to forms. Add article  2003_0031
# 	Processing author ...  Joaquim Madeira ( jmadeira@det.ua.pt ) added to authors
# 	Processing form for author  Joaquim Madeira ...added to forms. Add article  2003_0031
# 	Processing author ...  Beatriz Sousa Santos (  bss@det.ua.pt ) added to authors
# 	Processing form for author  Beatriz Sousa Santos ...added to forms. Add article  2003_0031
#
# Processing article ...  2003_0032 added to articles
# 	Processing author ...  Joaquim A Jorge ( jorgej@acm.org ) already in authors
# 	Processing form for author  Joaquim A Jorge ...already in forms. Add article  2003_0032
# 	Processing author ...  Nelson F Silva ( nelson.faria@netcabo.pt ) added to authors
# 	Processing form for author  Nelson F Silva ...added to forms. Add article  2003_0032
# 	Processing author ...  Tiago D Cardoso (  tiagocardoso@netcabo.pt ) added to authors
# 	Processing form for author  Tiago D Cardoso ...added to forms. Add article  2003_0032
#
# Processing article ...  2003_0033 added to articles
# 	Processing author ...  Paulo Jorge Matos (  pmatos@ipb.pt ) added to authors
# 	Processing form for author  Paulo Jorge Matos ...added to forms. Add article  2003_0033
# 	Processing author ...  Pedro Rangel Henriques ( prh@di.uminho.pt ) added to authors
# 	Processing form for author  Pedro Rangel Henriques ...added to forms. Add article  2003_0033
#
# *** Finished file 2003EPCG ***
#
# *** Processing file 2004Interacao ***
# Processing article ...  2004_0007 added to articles
# 	Processing author ...  Luis Filipe Garcia ( luisbgarcia@estig.ipbeja.pt  ) added to authors
# 	Processing form for author  Luis Filipe Garcia ...added to forms. Add article  2004_0007
# 	Processing author ...  Luís Caldas Oliveira ( lco@inesc-id.pt ) added to authors
# 	Processing form for author  Luís Caldas Oliveira ...added to forms. Add article  2004_0007
#
# Processing article ...  2004_0008 added to articles
# 	Processing author ...  Carlos Duarte (  cad@di.fc.ul.pt  ) added to authors
# 	Processing form for author  Carlos Duarte ...added to forms. Add article  2004_0008
# 	Processing author ...  Luís Carriço (  lmc@di.fc.ul.pt ) added to authors
# 	Processing form for author  Luís Carriço ...added to forms. Add article  2004_0008
#
# Processing article ...  2004_0009 added to articles
# 	Processing author ...  André Campos ( acampos@mega.ist.utl.pt ) added to authors
# 	Processing form for author  André Campos ...added to forms. Add article  2004_0009
# 	Processing author ...  Pedro Branco (  pjgb@immi.inesc.pt ) added to authors
# 	Processing form for author  Pedro Branco ...added to forms. Add article  2004_0009
# 	Processing author ...  Joaquim A Jorge ( jorgej@acm.org  ) already in authors
# 	Processing form for author  Joaquim A Jorge ...already in forms. Add article  2004_0009
#
# Processing article ...  2004_0011 added to articles
# 	Processing author ...  Paula André ( Paula.andre@ineti.pt ) added to authors
# 	Processing form for author  Paula André ...added to forms. Add article  2004_0011
# 	Processing author ...  Pedro Antunes ( paa@di.fc.ul.pt  ) added to authors
# 	Processing form for author  Pedro Antunes ...added to forms. Add article  2004_0011
#
# Processing article ...  2004_0012 added to articles
# 	Processing author ...  João Ramires ( joao.j.ramires@seg-social.pt ) added to authors
# 	Processing form for author  João Ramires ...added to forms. Add article  2004_0012
# 	Processing author ...  Pedro Antunes ( paa@di.fc.ul.pt ) already in authors
# 	Processing form for author  Pedro Antunes ...already in forms. Add article  2004_0012
#
# Processing article ...  2004_0013 added to articles
# 	Processing author ...  Andréa Poletto Sonza ( anjjo@terra.com.br  ) added to authors
# 	Processing form for author  Andréa Poletto Sonza ...added to forms. Add article  2004_0013
# 	Processing author ...  Cristiane Loureiro ( cris.bcloureiro@uol.com.br ) added to authors
# 	Processing form for author  Cristiane Loureiro ...added to forms. Add article  2004_0013
# 	Processing author ...  Lucila Santorosa ( Lucila.santarosa@ufrgs.br ) added to authors
# 	Processing form for author  Lucila Santorosa ...added to forms. Add article  2004_0013
#
# Processing article ...  2004_0014 added to articles
# 	Processing author ...  Manuela Aparício ( rnanuela@lusocredito.com  ) added to authors
# 	Processing form for author  Manuela Aparício ...added to forms. Add article  2004_0014
#
# Processing article ...  2004_0016 added to articles
# 	Processing author ...  Anabela Simões ( asimoes@fmh.utl.pt ) added to authors
# 	Processing form for author  Anabela Simões ...added to forms. Add article  2004_0016
# 	Processing author ...  José Carvalhais ( jcarvalhais@fmh.utl.pt  ) added to authors
# 	Processing form for author  José Carvalhais ...added to forms. Add article  2004_0016
# 	Processing author ...  Ana Gomes ( anagomes37@hotmail.com  ) added to authors
# 	Processing form for author  Ana Gomes ...added to forms. Add article  2004_0016
#
# Processing article ...  2004_0017 added to articles
# 	Processing author ...  Francisco dos S. Rebelo ( frebelo@frnh.utl.pt  ) added to authors
# 	Processing form for author  Francisco dos S. Rebelo ...added to forms. Add article  2004_0017
# 	Processing author ...  Ernesto Vilar Filgueiras ( ernestovilar@uol.corn.br ) added to authors
# 	Processing form for author  Ernesto Vilar Filgueiras ...added to forms. Add article  2004_0017
# 	Processing author ...  Raquel J. H. R Santos ( rsantos@frnh.utl.pt  ) added to authors
# 	Processing form for author  Raquel J. H. R Santos ...added to forms. Add article  2004_0017
# 	Processing author ...  Marta S. O. Pereira ( ergo_rns@hotrnail.com ) added to authors
# 	Processing form for author  Marta S. O. Pereira ...added to forms. Add article  2004_0017
# 	Processing author ...  José A. C.S Reis ( tz_reis@hotrnail.com ) added to authors
# 	Processing form for author  José A. C.S Reis ...added to forms. Add article  2004_0017
#
# Processing article ...  2004_0018 added to articles
# 	Processing author ...  Anamaria Moraes ( ergonana@terra.com.br  ) added to authors
# 	Processing form for author  Anamaria Moraes ...added to forms. Add article  2004_0018
# 	Processing author ...  Robson Santos ( robson.s@terra.com.br ) added to authors
# 	Processing form for author  Robson Santos ...added to forms. Add article  2004_0018
#
# Processing article ...  2004_0019 added to articles
# 	Processing author ...  M. Emília C. Duarte ( emiliaduarte@hotmail.com  ) added to authors
# 	Processing form for author  M. Emília C. Duarte ...added to forms. Add article  2004_0019
# 	Processing author ...  F. Rebelo ( frebelo@fmh.utl.pt  ) added to authors
# 	Processing form for author  F. Rebelo ...added to forms. Add article  2004_0019
#
# Processing article ...  2004_0020 added to articles
# 	Processing author ...  Eduardo Rangel Brandão (  ebrandao@rdc.puc-rio.br  ) added to authors
# 	Processing form for author  Eduardo Rangel Brandão ...added to forms. Add article  2004_0020
# 	Processing author ...  Anamaria Moraes ( moraergo@rdc.puc-rio.br  ) already in authors
# 	Processing form for author  Anamaria Moraes ...already in forms. Add article  2004_0020
#
# Processing article ...  2004_0021 added to articles
# 	Processing author ...  Luiz Agner ( agner@ism.com.br ) added to authors
# 	Processing form for author  Luiz Agner ...added to forms. Add article  2004_0021
# 	Processing author ...  Anamaria Moraes ( moraergo@rdc.puc-rio.br ) already in authors
# 	Processing form for author  Anamaria Moraes ...already in forms. Add article  2004_0021
#
# Processing article ...  2004_0023 added to articles
# 	Processing author ...  José Miguel Salles Dias ( miguel.Dias@iscte.pt ) already in authors
# 	Processing form for author  José Miguel Salles Dias ...already in forms. Add article  2004_0023
# 	Processing author ...  Nádia Jamal ( nadia.Jamal@iscte.pt ) added to authors
# 	Processing form for author  Nádia Jamal ...added to forms. Add article  2004_0023
# 	Processing author ...  Pedro Silva ( pedro.silva@iscte.pt ) added to authors
# 	Processing form for author  Pedro Silva ...added to forms. Add article  2004_0023
# 	Processing author ...  Rafael Bastos ( rafael.bastos@iscte.pt ) added to authors
# 	Processing form for author  Rafael Bastos ...added to forms. Add article  2004_0023
#
# Processing article ...  2004_0024 added to articles
# 	Processing author ...  José Miguel Salles Dias ( miguel.Dias@iscte.pt ) already in authors
# 	Processing form for author  José Miguel Salles Dias ...already in forms. Add article  2004_0024
# 	Processing author ...  Rafael Bastos ( Rafael.Bastos@iscte.pt ) already in authors
# 	Processing form for author  Rafael Bastos ...already in forms. Add article  2004_0024
# 	Processing author ...  Pedro Santos ( pedro.santos@iscte.pt ) already in authors
# 	Processing form for author  Pedro Santos ...already in forms. Add article  2004_0024
# 	Processing author ...  Luis Monteiro ( luis.monteiro@iscte.p ) added to authors
# 	Processing form for author  Luis Monteiro ...added to forms. Add article  2004_0024
# 	Processing author ...  Joaquim Canhoto ( jgsilva@montepiogeral.pt ) added to authors
# 	Processing form for author  Joaquim Canhoto ...added to forms. Add article  2004_0024
#
# Processing article ...  2004_0025 added to articles
# 	Processing author ...  André O. Falcão (  afalcao@di.fc.ul.pt ) added to authors
# 	Processing form for author  André O. Falcão ...added to forms. Add article  2004_0025
# 	Processing author ...  Manuel Próspero Santos ( ps@di.fct.unl.pt ) already in authors
# 	Processing form for author  Manuel Próspero Santos ...already in forms. Add article  2004_0025
#
# Processing article ...  2004_0026 added to articles
# 	Processing author ...  Alcínia Z. Sampaio ( zita@civil.ist.utl.pt  ) added to authors
# 	Processing form for author  Alcínia Z. Sampaio ...added to forms. Add article  2004_0026
# 	Processing author ...  Pedro G. Henriques ( pgameiro@civil.ist.utl.pt  ) added to authors
# 	Processing form for author  Pedro G. Henriques ...added to forms. Add article  2004_0026
# 	Processing author ...  Pedro Studer (  ) added to authors
# 	Processing author ...  Rui Luizi (  ) added to authors
#
# Processing article ...  2004_0027 added to articles
# 	Processing author ...  Ana Paula t Cláudio ( apc@di.fc.ul.pt ) added to authors
# 	Processing form for author  Ana Paula t Cláudio ...added to forms. Add article  2004_0027
# 	Processing author ...  Maria Beatriz Carmo ( bc@di.fc.ul.pt  ) added to authors
# 	Processing form for author  Maria Beatriz Carmo ...added to forms. Add article  2004_0027
# 	Processing author ...  João duarte Cunha ( jdc@di.fc.ul.pt ) added to authors
# 	Processing form for author  João duarte Cunha ...added to forms. Add article  2004_0027
#
# Processing article ...  2004_0029 added to articles
# 	Processing author ...  Teresa Chambel ( tc@di.fc.ul.pt  ) added to authors
# 	Processing form for author  Teresa Chambel ...added to forms. Add article  2004_0029
# 	Processing author ...  Nuno Guimarães ( nmg@di.fc.ul.pt  ) added to authors
# 	Processing form for author  Nuno Guimarães ...added to forms. Add article  2004_0029
#
# Processing article ...  2004_0030 added to articles
# 	Processing author ...  Pedro F. Campos ( pcampos@uma.pt ) added to authors
# 	Processing form for author  Pedro F. Campos ...added to forms. Add article  2004_0030
# 	Processing author ...  Nuno J. Nunes ( njn@uma.pt  ) added to authors
# 	Processing form for author  Nuno J. Nunes ...added to forms. Add article  2004_0030
#
# Processing article ...  2004_0031 added to articles
# 	Processing author ...  Luís Romero ( lmcr@di.fct.unl.pt  ) added to authors
# 	Processing form for author  Luís Romero ...added to forms. Add article  2004_0031
# 	Processing author ...  Jorge Santiago ( jms@di.fct.unl.pt  ) added to authors
# 	Processing form for author  Jorge Santiago ...added to forms. Add article  2004_0031
# 	Processing author ...  Nuno Correia ( nmc@di.fct.unl.pt  ) added to authors
# 	Processing form for author  Nuno Correia ...added to forms. Add article  2004_0031
#
# Processing article ...  2004_0032 added to articles
# 	Processing author ...  Lia Patrício ( lpatric@fe.up.pt ) added to authors
# 	Processing form for author  Lia Patrício ...added to forms. Add article  2004_0032
# 	Processing author ...  João Falcão Cunha (  jfcunha@fe.up.pt ) added to authors
# 	Processing form for author  João Falcão Cunha ...added to forms. Add article  2004_0032
# 	Processing author ...  Raymond P. Fisk ( rfisk@uno.edu ) added to authors
# 	Processing form for author  Raymond P. Fisk ...added to forms. Add article  2004_0032
#
# Processing article ...  2004_0033 added to articles
# 	Processing author ...  José Creissac Campos ( jose.campos@di.uminho.pt ) added to authors
# 	Processing form for author  José Creissac Campos ...added to forms. Add article  2004_0033
#
# Processing article ...  2004_0034 added to articles
# 	Processing author ...  Joana Pereira ( joanaper@netcabo.pt ) added to authors
# 	Processing form for author  Joana Pereira ...added to forms. Add article  2004_0034
# 	Processing author ...  Carriço Luís (   lmc@di.fo.ui.pt ) added to authors
# 	Processing form for author  Carriço Luís ...added to forms. Add article  2004_0034
#
# Processing article ...  2004_0036 added to articles
# 	Processing author ...  Daniel Gonçalves ( djvg@gia.ist.utl.pt ) already in authors
# 	Processing form for author  Daniel Gonçalves ...already in forms. Add article  2004_0036
# 	Processing author ...  Joaquim A. Jorge ( jorgej@acm.org  ) added to authors
# 	Processing form for author  Joaquim A. Jorge ...added to forms. Add article  2004_0036
#
# Processing article ...  2004_0037 added to articles
# 	Processing author ...  Cristina Gouveia ( gouveia@alum.mit.edu ) added to authors
# 	Processing form for author  Cristina Gouveia ...added to forms. Add article  2004_0037
# 	Processing author ...  Maria João Silva ( mjosilva@e se. i pp.pt  ) added to authors
# 	Processing form for author  Maria João Silva ...added to forms. Add article  2004_0037
# 	Processing author ...  Paulo Rosa ( par@sapo .pt ) added to authors
# 	Processing form for author  Paulo Rosa ...added to forms. Add article  2004_0037
#
# Processing article ...  2004_0038 added to articles
# 	Processing author ...  Norman Noronha ( normann@di.fc.ul.pt  ) added to authors
# 	Processing form for author  Norman Noronha ...added to forms. Add article  2004_0038
# 	Processing author ...  Mário J. Silva ( mjs@di.fc.ul.pt  ) added to authors
# 	Processing form for author  Mário J. Silva ...added to forms. Add article  2004_0038
#
# Processing article ...  2004_0039 added to articles
# 	Processing author ...  Marco Sá ( marcosa@di.fc.ul.pt  ) added to authors
# 	Processing form for author  Marco Sá ...added to forms. Add article  2004_0039
# 	Processing author ...  Luís Carriço ( lmc@di.fc.ul.pt  ) already in authors
# 	Processing form for author  Luís Carriço ...already in forms. Add article  2004_0039
#
# Processing article ...  2004_0040 added to articles
# 	Processing author ...  José Miguel Salles Dias ( miguel.dias@iscte.pt  ) already in authors
# 	Processing form for author  José Miguel Salles Dias ...already in forms. Add article  2004_0040
# 	Processing author ...  Marisa Aurélio (  marisaaurelio@iscte.pt  ) added to authors
# 	Processing form for author  Marisa Aurélio ...added to forms. Add article  2004_0040
# 	Processing author ...  Helder Carvalho ( heldercarvalho@iscte.pt  ) added to authors
# 	Processing form for author  Helder Carvalho ...added to forms. Add article  2004_0040
# 	Processing author ...  Luis Rosário ( lbrosario@mail.telepac.pt  ) added to authors
# 	Processing form for author  Luis Rosário ...added to forms. Add article  2004_0040
# 	Processing author ...  Luis Silva Carvalho ( fisiologia@mail.telepac.pt  ) added to authors
# 	Processing form for author  Luis Silva Carvalho ...added to forms. Add article  2004_0040
# 	Processing author ...  Isabel Rocha ( Instituto de Fisiologia ) added to authors
#
# Processing article ...  2004_0041 added to articles
# 	Processing author ...  Tiago Brito ( tmtb@mega.ist.utl.pt ) added to authors
# 	Processing form for author  Tiago Brito ...added to forms. Add article  2004_0041
# 	Processing author ...  Manuel J. Fonseca ( mjf@inesc-id.pt ) added to authors
# 	Processing form for author  Manuel J. Fonseca ...added to forms. Add article  2004_0041
# 	Processing author ...  Joaquim A. Jorge ( jorgej@acm.org  ) already in authors
# 	Processing form for author  Joaquim A. Jorge ...already in forms. Add article  2004_0041
#
# Processing article ...  2004_0042 added to articles
# 	Processing author ...  José Miguel Salles Dias ( miguel.dias@iscte.pt  ) already in authors
# 	Processing form for author  José Miguel Salles Dias ...already in forms. Add article  2004_0042
# 	Processing author ...  Juana Dehanov ( juana@netcabo.pt  ) added to authors
# 	Processing form for author  Juana Dehanov ...added to forms. Add article  2004_0042
# 	Processing author ...  Carolina Cabral ( carolinacabral@netcabo.p ) added to authors
# 	Processing form for author  Carolina Cabral ...added to forms. Add article  2004_0042
# 	Processing author ...  Antonio Carola (  a.c@oninetspeed.pt ) added to authors
# 	Processing form for author  Antonio Carola ...added to forms. Add article  2004_0042
#
# Processing article ...  2004_0044 added to articles
# 	Processing author ...  Leonor Moniz Pereira ( lmpereira@fmh.utl.pt ) added to authors
# 	Processing form for author  Leonor Moniz Pereira ...added to forms. Add article  2004_0044
# 	Processing author ...  Cristina Espadinha ( cespadinha@fmh.utl.pt ) added to authors
# 	Processing form for author  Cristina Espadinha ...added to forms. Add article  2004_0044
#
# Processing article ...  2004_0045 added to articles
# 	Processing author ...  Leonel D. Deusdado ( leodeus@ipb.pt  ) added to authors
# 	Processing form for author  Leonel D. Deusdado ...added to forms. Add article  2004_0045
#
# Processing article ...  2004_0046 added to articles
# 	Processing author ...  Samuel Silva ( sss@ieeta.pt  ) already in authors
# 	Processing form for author  Samuel Silva ...already in forms. Add article  2004_0046
# 	Processing author ...  Joaquim Madeira ( jmadeira@det.ua.pt ) already in authors
# 	Processing form for author  Joaquim Madeira ...already in forms. Add article  2004_0046
# 	Processing author ...  Beatriz Sousa Santos ( bss@det.ua.pt ) already in authors
# 	Processing form for author  Beatriz Sousa Santos ...already in forms. Add article  2004_0046
#
# Processing article ...  2004_0046 already in articles
# 	Processing author ...  Sofia Gameiro (  sofia.gameiro@coimbra.ccg.pt  ) already in authors
# 	Processing form for author  Sofia Gameiro ...already in forms. Add article  2004_0046
# 	Processing author ...  António Freitas ( António.Freitas@coimbra.ccg.pt ) added to authors
# 	Processing form for author  António Freitas ...added to forms. Add article  2004_0046
# 	Processing author ...  Luís Almeida ( L uis.Almeida@coimbra.ccg.pt ) already in authors
# 	Processing form for author  Luís Almeida ...already in forms. Add article  2004_0046
# 	Processing author ...  Pedro Pereira ( Pedro.Pereira@ccg.pt  ) already in authors
# 	Processing form for author  Pedro Pereira ...already in forms. Add article  2004_0046
# 	Processing author ...  Adérito Marcos ( marcos@dsi.uminho.pt  ) already in authors
# 	Processing form for author  Adérito Marcos ...already in forms. Add article  2004_0046
#
# Processing article ...  2004_0047 added to articles
# 	Processing author ...  José Guilherme Santa Rosa ( guilherrn@rdc.puc-rio.br  ) added to authors
# 	Processing form for author  José Guilherme Santa Rosa ...added to forms. Add article  2004_0047
# 	Processing author ...  Anamaria Moarais ( rnoraergo@rdc.puc-rio.br  ) added to authors
# 	Processing form for author  Anamaria Moarais ...added to forms. Add article  2004_0047
#
# Processing article ...  2004_0048 added to articles
# 	Processing author ...  José Guilherme Santa Rosa ( guilherrn@rdc.puc-rio.br  ) already in authors
# 	Processing form for author  José Guilherme Santa Rosa ...already in forms. Add article  2004_0048
# 	Processing author ...  Anamaria Moarais ( rnoraergo@rdc.puc-rio.br  ) already in authors
# 	Processing form for author  Anamaria Moarais ...already in forms. Add article  2004_0048
#
# Processing article ...  2004_0049 added to articles
# 	Processing author ...  Mirian Dias Pontifícia ( mirian@rdc.puc-rio.br ) added to authors
# 	Processing form for author  Mirian Dias Pontifícia ...added to forms. Add article  2004_0049
# 	Processing author ...  Anamaria Moarais ( moraergo@rdc.puc-rio.br ) already in authors
# 	Processing form for author  Anamaria Moarais ...already in forms. Add article  2004_0049
#
# Processing article ...  2004_0050 added to articles
# 	Processing author ...  Alcina Prata ( aprata@esce.ips.pt ) added to authors
# 	Processing form for author  Alcina Prata ...added to forms. Add article  2004_0050
# 	Processing author ...  Nuno Guimarães ( nmg@di.fc.ul.pt  ) already in authors
# 	Processing form for author  Nuno Guimarães ...already in forms. Add article  2004_0050
# 	Processing author ...  Piet Kommers ( P.A.M.Kommers@edte.utwente.nl ) added to authors
# 	Processing form for author  Piet Kommers ...added to forms. Add article  2004_0050
#
# Processing article ...  2004_0051 added to articles
# 	Processing author ...  Florin Zamfir ( florin@ieeta.pt  ) added to authors
# 	Processing form for author  Florin Zamfir ...added to forms. Add article  2004_0051
# 	Processing author ...  José Nunes ( jnunes@ca.ua.pt ) added to authors
# 	Processing form for author  José Nunes ...added to forms. Add article  2004_0051
# 	Processing author ...  Leonor Teixeira (  lteixeira@egi.ua.pt  ) added to authors
# 	Processing form for author  Leonor Teixeira ...added to forms. Add article  2004_0051
# 	Processing author ...  Óscar Mealha ( oern@ca.ua.pt  ) added to authors
# 	Processing form for author  Óscar Mealha ...added to forms. Add article  2004_0051
# 	Processing author ...  Beatriz Sousa Santos ( bss@ieeta.pt  ) already in authors
# 	Processing form for author  Beatriz Sousa Santos ...already in forms. Add article  2004_0051
#
# Processing article ...  2004_0052 added to articles
# 	Processing author ...  Hugo Miguel Gonçalves Rego ( hugo_rego@esav.ipv.pt ) added to authors
# 	Processing form for author  Hugo Miguel Gonçalves Rego ...added to forms. Add article  2004_0052
# 	Processing author ...  Tiago Henrique R.S. L. Moreira (  tiagorn@di.estv.ipv.pt ) added to authors
# 	Processing form for author  Tiago Henrique R.S. L. Moreira ...added to forms. Add article  2004_0052
# 	Processing author ...  Francisco J. García Penalvo ( fgarcia@usal.es ) added to authors
# 	Processing form for author  Francisco J. García Penalvo ...added to forms. Add article  2004_0052
#
# Processing article ...  2004_0053 added to articles
# 	Processing author ...  Miguel Gonçalves ( mg@fe.up.pt  ) added to authors
# 	Processing form for author  Miguel Gonçalves ...added to forms. Add article  2004_0053
# 	Processing author ...  João Falcão Cunha ( jfcunha@fe.up.pt  ) already in authors
# 	Processing form for author  João Falcão Cunha ...already in forms. Add article  2004_0053
# 	Processing author ...  Lia Patrício ( lpatric@fe.up.pt  ) already in authors
# 	Processing form for author  Lia Patrício ...already in forms. Add article  2004_0053
#
# Processing article ...  2004_0051 already in articles
# 	Processing author ...  Alexandre Mano ( amano@netcabo.pt  ) added to authors
# 	Processing form for author  Alexandre Mano ...added to forms. Add article  2004_0051
# 	Processing author ...  José C. Campos ( jose.campos@di.uminho.pt  ) added to authors
# 	Processing form for author  José C. Campos ...added to forms. Add article  2004_0051
#
# *** Finished file 2004Interacao ***
#
# *** Processing file 2005EPCG ***
# Processing article ...  2005_0005 added to articles
# 	Processing author ...  Samuel Silva ( sss@ieeta.pt  ) already in authors
# 	Processing form for author  Samuel Silva ...already in forms. Add article  2005_0005
# 	Processing author ...  Joaquim Madeira ( jmadeira@det.ua.pt ) already in authors
# 	Processing form for author  Joaquim Madeira ...already in forms. Add article  2005_0005
# 	Processing author ...  Beatriz Sousa Santos ( bss@det.ua.pt ) already in authors
# 	Processing form for author  Beatriz Sousa Santos ...already in forms. Add article  2005_0005
#
# Processing article ...  2005_0006 added to articles
# 	Processing author ...  Eunice Oliveira ( eunice@estg.ipleiria.pt ) added to authors
# 	Processing form for author  Eunice Oliveira ...added to forms. Add article  2005_0006
# 	Processing author ...  José Carlos Teixeira ( teixeira@mat.uc.pt ) added to authors
# 	Processing form for author  José Carlos Teixeira ...added to forms. Add article  2005_0006
#
# Processing article ...  2005_0007 added to articles
# 	Processing author ...  Fernando Pedro Birra ( fpb@di.fct.unl.pt  ) already in authors
# 	Processing form for author  Fernando Pedro Birra ...already in forms. Add article  2005_0007
# 	Processing author ...  Manuel Próspero Santos ( ps@di.fct.unl.pt  ) already in authors
# 	Processing form for author  Manuel Próspero Santos ...already in forms. Add article  2005_0007
#
# Processing article ...  2005_0008 added to articles
# 	Processing author ...  Helder M. A. Magalhães ( helder.magalhaes@fe.up.pt ) added to authors
# 	Processing form for author  Helder M. A. Magalhães ...added to forms. Add article  2005_0008
#
# Processing article ...  2005_0009 added to articles
# 	Processing author ...  Filipe Marreirosa ( filipe.marreiros@ccg.pt ) added to authors
# 	Processing form for author  Filipe Marreirosa ...added to forms. Add article  2005_0009
# 	Processing author ...  Adérito Marcos ( marcos@dsi.uminho.pt ) already in authors
# 	Processing form for author  Adérito Marcos ...already in forms. Add article  2005_0009
#
# Processing article ...  2005_0010 added to articles
# 	Processing author ...  José Miguel Salles Dias ( miguel.Dias@iscte.pt ) already in authors
# 	Processing form for author  José Miguel Salles Dias ...already in forms. Add article  2005_0010
# 	Processing author ...  António Pocinho ( ahpocinho@sapo.pt ) added to authors
# 	Processing form for author  António Pocinho ...added to forms. Add article  2005_0010
#
# Processing article ...  2005_0011 added to articles
# 	Processing author ...  José Braz Pereira ( jbraz@est.ips.pt ) already in authors
# 	Processing form for author  José Braz Pereira ...already in forms. Add article  2005_0011
# 	Processing author ...  João Madeiras Pereira ( jap@inesc.pt ) already in authors
# 	Processing form for author  João Madeiras Pereira ...already in forms. Add article  2005_0011
#
# Processing article ...  2005_0012 added to articles
# 	Processing author ...  Daniel Gonçalves ( daniel.goncalves@inesc-id.pt ) already in authors
# 	Processing form for author  Daniel Gonçalves ...already in forms. Add article  2005_0012
# 	Processing author ...  Joaquim A Jorge ( jaj@inesc-id.pt  ) already in authors
# 	Processing form for author  Joaquim A Jorge ...already in forms. Add article  2005_0012
#
# Processing article ...  2005_0013 added to articles
# 	Processing author ...  M. Beatriz Carmo ( bc@di.fc.ul.pt ) added to authors
# 	Processing form for author  M. Beatriz Carmo ...added to forms. Add article  2005_0013
# 	Processing author ...  A. Paula Cláudio ( apc@di.fc.ul.pt ) added to authors
# 	Processing form for author  A. Paula Cláudio ...added to forms. Add article  2005_0013
# 	Processing author ...  João D. Cunha ( jdc@di.fc.ul.pt ) added to authors
# 	Processing form for author  João D. Cunha ...added to forms. Add article  2005_0013
# 	Processing author ...  Helder Coelho ( hcoelho@di.fc.ul.pt ) added to authors
# 	Processing form for author  Helder Coelho ...added to forms. Add article  2005_0013
# 	Processing author ...  Miguel Silvestre ( msilvestre@gmail.com ) added to authors
# 	Processing form for author  Miguel Silvestre ...added to forms. Add article  2005_0013
# 	Processing author ...  Maria Pinto Albuquerque ( maria.albuquerque@iscte.pt  ) added to authors
# 	Processing form for author  Maria Pinto Albuquerque ...added to forms. Add article  2005_0013
#
# Processing article ...  2005_0014 added to articles
# 	Processing author ...  Maximino Bessa ( maxbessa@utad.pt ) added to authors
# 	Processing form for author  Maximino Bessa ...added to forms. Add article  2005_0014
# 	Processing author ...  António Coelho ( acoelho@utad.pt ) added to authors
# 	Processing form for author  António Coelho ...added to forms. Add article  2005_0014
# 	Processing author ...  João Paulo Moura ( jpmoura@utad.pt ) added to authors
# 	Processing form for author  João Paulo Moura ...added to forms. Add article  2005_0014
# 	Processing author ...  José Bulas Cruz ( jcruz@utad.pt ) added to authors
# 	Processing form for author  José Bulas Cruz ...added to forms. Add article  2005_0014
# 	Processing author ...  Fernando Nunes Ferreira ( fnf@fe.up.pt ) already in authors
# 	Processing form for author  Fernando Nunes Ferreira ...already in forms. Add article  2005_0014
# 	Processing author ...  Alan Chalmers ( alan.chalmers@cs.bris.ac.uk ) added to authors
# 	Processing form for author  Alan Chalmers ...added to forms. Add article  2005_0014
# 	Processing author ...  António Augusto Sousa ( aas@fe.up.pt ) already in authors
# 	Processing form for author  António Augusto Sousa ...already in forms. Add article  2005_0014
#
# Processing article ...  2005_0015 added to articles
# 	Processing author ...  Paulo Bernardes ( pbernardes@uaum.uminho.pt ) already in authors
# 	Processing form for author  Paulo Bernardes ...already in forms. Add article  2005_0015
# 	Processing author ...  Joaquim Madeira ( jmadeira@det.ua.pt ) already in authors
# 	Processing form for author  Joaquim Madeira ...already in forms. Add article  2005_0015
#
# Processing article ...  2005_0016 added to articles
# 	Processing author ...  Nuno Rodrigues ( nunorod@estg.ipleiria.pt ) added to authors
# 	Processing form for author  Nuno Rodrigues ...added to forms. Add article  2005_0016
# 	Processing author ...  Adriano lopes ( alopes@di.fct.unl.pt ) added to authors
# 	Processing form for author  Adriano lopes ...added to forms. Add article  2005_0016
# 	Processing author ...  Próspero Santos ( ps@di.fct.unl.pt ) added to authors
# 	Processing form for author  Próspero Santos ...added to forms. Add article  2005_0016
# 	Processing author ...  Gil Gonçalves ( gil@mat.uc.pt ) added to authors
# 	Processing form for author  Gil Gonçalves ...added to forms. Add article  2005_0016
#
# Processing article ...  2005_0017 added to articles
# 	Processing author ...  Samuel Silva ( sss@ieeta.pt ) already in authors
# 	Processing form for author  Samuel Silva ...already in forms. Add article  2005_0017
# 	Processing author ...  Joaquim Madeira ( jmadeira@det.ua.pt ) already in authors
# 	Processing form for author  Joaquim Madeira ...already in forms. Add article  2005_0017
# 	Processing author ...  Carlos Ferreira ( carlosf@egi.ua.pt ) added to authors
# 	Processing form for author  Carlos Ferreira ...added to forms. Add article  2005_0017
# 	Processing author ...  Beatriz Sousa Santos ( bss@det.ua.pt ) already in authors
# 	Processing form for author  Beatriz Sousa Santos ...already in forms. Add article  2005_0017
#
# Processing article ...  2005_0018 added to articles
# 	Processing author ...  Pedro Mogadouro Couto ( pcouto@utad.pt ) added to authors
# 	Processing form for author  Pedro Mogadouro Couto ...added to forms. Add article  2005_0018
# 	Processing author ...  Luís Gonzaga Magalhães ( lmagalha@utad.pt ) added to authors
# 	Processing form for author  Luís Gonzaga Magalhães ...added to forms. Add article  2005_0018
# 	Processing author ...  Ronaldo Gabriel ( rgabriel@utad.pt ) added to authors
# 	Processing form for author  Ronaldo Gabriel ...added to forms. Add article  2005_0018
# 	Processing author ...  Pedro Melo Pinto ( pmelo@utad.pt ) added to authors
# 	Processing form for author  Pedro Melo Pinto ...added to forms. Add article  2005_0018
#
# Processing article ...  2005_0020 added to articles
# 	Processing author ...  Ana Prata ( ana.prata@tagus.ist.utl.pt  ) added to authors
# 	Processing form for author  Ana Prata ...added to forms. Add article  2005_0020
# 	Processing author ...  Susana Lobão ( susana.lobao@tagus.ist.utl.pt  ) added to authors
# 	Processing form for author  Susana Lobão ...added to forms. Add article  2005_0020
# 	Processing author ...  Mário Rui Gomes ( mario.gomes@tagus.ist.utl.pt  ) added to authors
# 	Processing form for author  Mário Rui Gomes ...added to forms. Add article  2005_0020
#
# Processing article ...  2005_0021 added to articles
# 	Processing author ...  Tiago Martins ( tms.martins@di.fct.unl.pt ) added to authors
# 	Processing form for author  Tiago Martins ...added to forms. Add article  2005_0021
# 	Processing author ...  Nuno Correia ( nmc@di.fct.unl.pt ) already in authors
# 	Processing form for author  Nuno Correia ...already in forms. Add article  2005_0021
# 	Processing author ...  Filipe Barrenho ( l14066@alunos.uevora.pt ) added to authors
# 	Processing form for author  Filipe Barrenho ...added to forms. Add article  2005_0021
# 	Processing author ...  Teresa Romão ( tir@di.uevora.pt  ) added to authors
# 	Processing form for author  Teresa Romão ...added to forms. Add article  2005_0021
#
# Processing article ...  2005_0022 added to articles
# 	Processing author ...  Fernando Silva ( fernando.silva@estg.ipleiria.pt ) added to authors
# 	Processing form for author  Fernando Silva ...added to forms. Add article  2005_0022
# 	Processing author ...  Alexandrino Gonçalves ( alex@estg.ipleiria.pt ) already in authors
# 	Processing form for author  Alexandrino Gonçalves ...already in forms. Add article  2005_0022
#
# Processing article ...  2005_0023 added to articles
# 	Processing author ...  Paulo Correia Moreira ( a19969@alunos. det.ua.pt ) added to authors
# 	Processing form for author  Paulo Correia Moreira ...added to forms. Add article  2005_0023
# 	Processing author ...  Mário cruz ( a23487@alunos. det.ua.pt ) added to authors
# 	Processing form for author  Mário cruz ...added to forms. Add article  2005_0023
# 	Processing author ...  Paulo Dias ( paulo.dias@det. ua.pt ) added to authors
# 	Processing form for author  Paulo Dias ...added to forms. Add article  2005_0023
# 	Processing author ...  Paulo Martins (  a21097@alunos. det.ua.pt ) added to authors
# 	Processing form for author  Paulo Martins ...added to forms. Add article  2005_0023
# 	Processing author ...  Rui Gomes ( a22282@alunos. det.ua.pt ) added to authors
# 	Processing form for author  Rui Gomes ...added to forms. Add article  2005_0023
# 	Processing author ...  Joaquim Madeira (  jmadeira@det. ua.pt ) already in authors
# 	Processing form for author  Joaquim Madeira ...already in forms. Add article  2005_0023
# 	Processing author ...  Manuel Bernardo Cunha ( mbc@det.ua.pt ) added to authors
# 	Processing form for author  Manuel Bernardo Cunha ...added to forms. Add article  2005_0023
# 	Processing author ...  Beatriz Sousa Santos (  bss@det.ua.pt ) already in authors
# 	Processing form for author  Beatriz Sousa Santos ...already in forms. Add article  2005_0023
#
# Processing article ...  2005_0024 added to articles
# 	Processing author ...  Bruno Miguel Oliveira ( bruno.oliveira@dcc.online.pt  ) added to authors
# 	Processing form for author  Bruno Miguel Oliveira ...added to forms. Add article  2005_0024
# 	Processing author ...  Pedro Miguel Ângelo ( bruno.oliveira@ccg.pt  ) added to authors
# 	Processing form for author  Pedro Miguel Ângelo ...added to forms. Add article  2005_0024
#
# Processing article ...  2005_0025 added to articles
# 	Processing author ...  João Sena Marcos (  joaosenamarcos@sapo.pt ) added to authors
# 	Processing form for author  João Sena Marcos ...added to forms. Add article  2005_0025
# 	Processing author ...  José Miguel Salles Dias ( miguel.dias@iscte.pt ) already in authors
# 	Processing form for author  José Miguel Salles Dias ...already in forms. Add article  2005_0025
# 	Processing author ...  António Calado Lopes (  antonio.calado@iscte.pt ) added to authors
# 	Processing form for author  António Calado Lopes ...added to forms. Add article  2005_0025
#
# Processing article ...  2005_0026 added to articles
# 	Processing author ...  Filipe Marques Dias ( fil@immi.inesc-id.pt ) already in authors
# 	Processing form for author  Filipe Marques Dias ...already in forms. Add article  2005_0026
# 	Processing author ...  Joaquim A. Jorge ( jorgej@acm.org ) already in authors
# 	Processing form for author  Joaquim A. Jorge ...already in forms. Add article  2005_0026
#
# Processing article ...  2005_0027 added to articles
# 	Processing author ...  Daniel Lourenço ( daniel.antunes.lourenco@gmail.com ) added to authors
# ...
#
# Processing article ...  2006_0050 added to articles
# 	Processing author ...  Mariana Cerejo (  ) added to authors
# 	Processing author ...  José Santos (  ) added to authors
# 	Processing author ...  Alfredo Ferreira (  ) already in authors
# 	Processing author ...  Manuel J. Fonseca (  mjf@inesc-id.pt ) already in authors
# 	Processing form for author  Manuel J. Fonseca ...already in forms. Add article  2006_0050
# 	Processing author ...  Joaquim A. Jorge ( jorgej@acm.org ) already in authors
# 	Processing form for author  Joaquim A. Jorge ...already in forms. Add article  2006_0050
#
# Processing article ...  2006_0051 added to articles
# 	Processing author ...  Tiago Guerreiro ( tjvg@immi.inesc.pt ) already in authors
# 	Processing form for author  Tiago Guerreiro ...already in forms. Add article  2006_0051
# 	Processing author ...  Vitor Fernandes (  vmnf@immi.inesc.pt ) already in authors
# 	Processing form for author  Vitor Fernandes ...already in forms. Add article  2006_0051
# 	Processing author ...  Bruno Araújo ( brar@immi.inesc.pt ) added to authors
# 	Processing form for author  Bruno Araújo ...added to forms. Add article  2006_0051
# 	Processing author ...  Joaquim Jorge ( jaj@acm.org ) added to authors
# 	Processing form for author  Joaquim Jorge ...added to forms. Add article  2006_0051
# 	Processing author ...  João Pereira ( jap@inesc.pt ) added to authors
# 	Processing form for author  João Pereira ...added to forms. Add article  2006_0051
#
# *** Finished file 2006Interacao ***
#
# *** Processing file 2007EPCG ***
# Processing article ...  2007_0005 added to articles
# 	Processing author ...  Elizabeth S. Carvalho ( ecarvalho@dsi . uminho .pt ) already in authors
# 	Processing form for author  Elizabeth S. Carvalho ...already in forms. Add article  2007_0005
# 	Processing author ...  Maribel Yasmina Santos ( maribel@dsi.uminho.pt ) added to authors
# 	Processing form for author  Maribel Yasmina Santos ...added to forms. Add article  2007_0005
# 	Processing author ...  Adérito Fernandes Marcos ( marcos@dsi.uminho.pt  ) added to authors
# 	Processing form for author  Adérito Fernandes Marcos ...added to forms. Add article  2007_0005
# 	Processing author ...  Paulo Miguel C. Brito ( pbrito@dsi.uminho.pt ) added to authors
# 	Processing form for author  Paulo Miguel C. Brito ...added to forms. Add article  2007_0005
#
# Processing article ...  2007_0006 added to articles
# 	Processing author ...  Carlos Campos (  cjc@isep.ipp.pt  ) already in authors
# 	Processing form for author  Carlos Campos ...already in forms. Add article  2007_0006
# 	Processing author ...  João Miguel Leitão ( jml@isep.ipp.pt  ) added to authors
# 	Processing form for author  João Miguel Leitão ...added to forms. Add article  2007_0006
# 	Processing author ...  Carlos M. Rodrigues (  cmr@fe.up.pt  ) added to authors
# 	Processing form for author  Carlos M. Rodrigues ...added to forms. Add article  2007_0006
#
# Processing article ...  2007_0007 added to articles
# 	Processing author ...  Sofia Reis ( sofiareis@hotmail.com ) added to authors
# 	Processing form for author  Sofia Reis ...added to forms. Add article  2007_0007
# 	Processing author ...  Manuel Próspero dos Santos ( ps@di.fct.unl.pt  ) added to authors
# 	Processing form for author  Manuel Próspero dos Santos ...added to forms. Add article  2007_0007
#
# Processing article ...  2007_0008 added to articles
# 	Processing author ...  Carlos Afonso Rebelo ( ei99056@fe.up.pt  ) added to authors
# 	Processing form for author  Carlos Afonso Rebelo ...added to forms. Add article  2007_0008
# 	Processing author ...  António Fernando Coelho ( acoelho@fe.up.pt  ) already in authors
# 	Processing form for author  António Fernando Coelho ...already in forms. Add article  2007_0008
# 	Processing author ...  Filipe Cruz ( fcruz@fe.up.pt  ) added to authors
# 	Processing form for author  Filipe Cruz ...added to forms. Add article  2007_0008
# 	Processing author ...  António Augusto de Sousa ( aas@fe.up.pt  ) added to authors
# 	Processing form for author  António Augusto de Sousa ...added to forms. Add article  2007_0008
# 	Processing author ...  Fernando Nunes Ferreira ( fnf@fe.up.pt  ) already in authors
# 	Processing form for author  Fernando Nunes Ferreira ...already in forms. Add article  2007_0008
#
# Processing article ...  2007_0010 added to articles
# 	Processing author ...  Ricardo Casaleiro ( a@alunos.det.ua .pt ) added to authors
# 	Processing form for author  Ricardo Casaleiro ...added to forms. Add article  2007_0010
# 	Processing author ...  Ricardo Seco ( a@alunos.det.ua.pt ) added to authors
# 	Processing form for author  Ricardo Seco ...added to forms. Add article  2007_0010
# 	Processing author ...  Guilherme Campos ( agrcapos@det.ua.pt  ) added to authors
# 	Processing form for author  Guilherme Campos ...added to forms. Add article  2007_0010
# 	Processing author ...  Paulo Dias ( paulo.dias@ua.pt ) already in authors
# 	Processing form for author  Paulo Dias ...already in forms. Add article  2007_0010
# 	Processing author ...  Beatriz Sousa Santos ( bss@det.ua.pt  ) already in authors
# 	Processing form for author  Beatriz Sousa Santos ...already in forms. Add article  2007_0010
#
# Processing article ...  2007_0011 added to articles
# 	Processing author ...  José F. Martins ( jmartins@docentes . ismai.pt  ) added to authors
# 	Processing form for author  José F. Martins ...added to forms. Add article  2007_0011
# 	Processing author ...  Jorge A. Silva ( jsilva@fe.up.pt ) added to authors
# 	Processing form for author  Jorge A. Silva ...added to forms. Add article  2007_0011
# 	Processing author ...  A. Augusto Sousa ( augusto.sousa@fe.up.pt  ) added to authors
# 	Processing form for author  A. Augusto Sousa ...added to forms. Add article  2007_0011
#
# Processing article ...  2007_0012 added to articles
# 	Processing author ...  Vasco Costa ( vasco.costa@ist.utl.pt  ) added to authors
# 	Processing form for author  Vasco Costa ...added to forms. Add article  2007_0012
# 	Processing author ...  João Madeiras Pereira ( jap@inesc.p ) already in authors
# 	Processing form for author  João Madeiras Pereira ...already in forms. Add article  2007_0012
# 	Processing author ...  José Miguel Salles Dias ( miguel.dias@iscte.pt ) already in authors
# 	Processing form for author  José Miguel Salles Dias ...already in forms. Add article  2007_0012
#
# Processing article ...  2007_0013 added to articles
# 	Processing author ...  Luís Paulo Santos ( psantos@di.uminho.pt ) added to authors
# 	Processing form for author  Luís Paulo Santos ...added to forms. Add article  2007_0013
# 	Processing author ...  João Luís Sobral ( jls@di .uminho .pt  ) added to authors
# 	Processing form for author  João Luís Sobral ...added to forms. Add article  2007_0013
#
# Processing article ...  2007_0014 added to articles
# 	Processing author ...  R. Bastos (  ) added to authors
# 	Processing author ...  M.S. Dias (  ) added to authors
#
# Processing article ...  2007_0015 added to articles
# 	Processing author ...  Vasco Gervásio ( vmrg@immi.inesc-id.pt ) added to authors
# 	Processing form for author  Vasco Gervásio ...added to forms. Add article  2007_0015
# 	Processing author ...  Joaquim A. Jorge ( jorgej@acm.org  ) already in authors
# 	Processing form for author  Joaquim A. Jorge ...already in forms. Add article  2007_0015
#
# Processing article ...  2007_0017 added to articles
# 	Processing author ...  Samuel Silva ( sss@ua.pt  ) already in authors
# 	Processing form for author  Samuel Silva ...already in forms. Add article  2007_0017
# 	Processing author ...  Joaquim Madeira ( jmadeira@ua.pt  ) already in authors
# 	Processing form for author  Joaquim Madeira ...already in forms. Add article  2007_0017
# 	Processing author ...  Frutuoso Silva ( fsilva@di. ubi. pt ) added to authors
# 	Processing form for author  Frutuoso Silva ...added to forms. Add article  2007_0017
# 	Processing author ...  Beatriz Sousa Santos ( bss@ua.pt  ) already in authors
# 	Processing form for author  Beatriz Sousa Santos ...already in forms. Add article  2007_0017
#
# Processing article ...  2007_0018 added to articles
# 	Processing author ...  Rui Rodrigues ( rsrodrigues@di.estv.ipv.pt  ) already in authors
# 	Processing form for author  Rui Rodrigues ...added to forms. Add article  2007_0018
# 	Processing author ...  José Morgado ( fmorgado@di.estv.ipv.pt  ) added to authors
# 	Processing form for author  José Morgado ...added to forms. Add article  2007_0018
# 	Processing author ...  Frutuoso Silva ( fsilva@di. ubi. pt ) already in authors
# 	Processing form for author  Frutuoso Silva ...already in forms. Add article  2007_0018
# 	Processing author ...  Abel Gomes ( agomes@di.ubi.pt  ) already in authors
# 	Processing form for author  Abel Gomes ...already in forms. Add article  2007_0018
#
# Processing article ...  2007_0019 added to articles
# 	Processing author ...  João Proença ( jrpp@mega .ist.utl.pt ) added to authors
# 	Processing form for author  João Proença ...added to forms. Add article  2007_0019
# 	Processing author ...  Joaquim A. Jorge ( jorgej@acm.org  ) already in authors
# 	Processing form for author  Joaquim A. Jorge ...already in forms. Add article  2007_0019
# 	Processing author ...  Mário Costa Sousa ( mario@cpsc.ucalgary.ca  ) added to authors
# 	Processing form for author  Mário Costa Sousa ...added to forms. Add article  2007_0019
#
# Processing article ...  2007_0020 added to articles
# 	Processing author ...  Daniel Gonçalves ( daniel.goncalves@inesc-id.pt  ) already in authors
# 	Processing form for author  Daniel Gonçalves ...already in forms. Add article  2007_0020
# 	Processing author ...  Tiago Guerreiro ( tjvg@inesc-id.pt  ) already in authors
# 	Processing form for author  Tiago Guerreiro ...already in forms. Add article  2007_0020
# 	Processing author ...  Joaquim A. Jorge (  jaj@inesc-id.pt  ) already in authors
# 	Processing form for author  Joaquim A. Jorge ...already in forms. Add article  2007_0020
#
# Processing article ...  2007_0021 added to articles
# 	Processing author ...  Rui Jesus ( rjesus@deetc.isel.ipl .pt ) added to authors
# 	Processing form for author  Rui Jesus ...added to forms. Add article  2007_0021
# 	Processing author ...  Edgar Santos (  ) added to authors
# 	Processing author ...  Rute Frias (  ) added to authors
# 	Processing author ...  Nuno Correia (  nmc@di.fct.unl .pt  ) already in authors
# 	Processing form for author  Nuno Correia ...already in forms. Add article  2007_0021
#
# Processing article ...  2007_0022 added to articles
# 	Processing author ...  Ricardo Jota (  ) already in authors
# 	Processing author ...  Bruno Araújo (  ) already in authors
# 	Processing author ...  Luís Bruno (  ) added to authors
# 	Processing author ...  José Dias (  ) added to authors
# 	Processing author ...  João M. Pereira (  ) already in authors
# 	Processing author ...  Joaquim A. Jorge (  jaj@inesc-id.pt  ) already in authors
# 	Processing form for author  Joaquim A. Jorge ...already in forms. Add article  2007_0022
#
# Processing article ...  2007_0024 added to articles
# 	Processing author ...  João Garcia Barbosa ( jbarbosa@di.uminho.pt  ) added to authors
# 	Processing form for author  João Garcia Barbosa ...added to forms. Add article  2007_0024
# 	Processing author ...  João Luís Sobral ( jls@di.uminho.pt  ) already in authors
# 	Processing form for author  João Luís Sobral ...already in forms. Add article  2007_0024
# 	Processing author ...  Alberto José Proença ( aproenca@di.uminho.pt  ) added to authors
# 	Processing form for author  Alberto José Proença ...added to forms. Add article  2007_0024
#
# Processing article ...  2007_0025 added to articles
# 	Processing author ...  Paulo Bernardes ( pbernardes@uaum.uminho.pt  ) already in authors
# 	Processing form for author  Paulo Bernardes ...already in forms. Add article  2007_0025
# 	Processing author ...  Joaquim Madeira ( jmadeira@ua.pt ) already in authors
# 	Processing form for author  Joaquim Madeira ...already in forms. Add article  2007_0025
# 	Processing author ...  Maria Manuela Martins ( mmmartins@uaum.uminho.pt ) added to authors
# 	Processing form for author  Maria Manuela Martins ...added to forms. Add article  2007_0025
#
# Processing article ...  2007_0026 added to articles
# 	Processing author ...  Pedro Amaral ( pedroamaral@ua.pt  ) added to authors
# 	Processing form for author  Pedro Amaral ...added to forms. Add article  2007_0026
# 	Processing author ...  Francisco Sales ( umes@huc.min-saude.pt ) added to authors
# 	Processing form for author  Francisco Sales ...added to forms. Add article  2007_0026
# 	Processing author ...  João Paulo Silva Cunha ( jcunha@det.ua.pt ) added to authors
# 	Processing form for author  João Paulo Silva Cunha ...added to forms. Add article  2007_0026
# 	Processing author ...  Paulo Dias ( paulodias@ua.pt ) already in authors
# 	Processing form for author  Paulo Dias ...already in forms. Add article  2007_0026
# 	Processing author ...  José Maria Fernandes ( jfernan@det.ua.pt  ) added to authors
# 	Processing form for author  José Maria Fernandes ...added to forms. Add article  2007_0026
#
# Processing article ...  2007_0027 added to articles
# 	Processing author ...  Paulo Pombinho Matos ( ppombinho@lasige.di.fc.ul.pt ) already in authors
# 	Processing form for author  Paulo Pombinho Matos ...already in forms. Add article  2007_0027
# 	Processing author ...  Maria Beatriz Carmo ( bc@di.fc.ul.pt   ) already in authors
# 	Processing form for author  Maria Beatriz Carmo ...already in forms. Add article  2007_0027
# 	Processing author ...  Ana Paula Afonso ( apa@di.fc.ul.pt  ) already in authors
# 	Processing form for author  Ana Paula Afonso ...already in forms. Add article  2007_0027
#
# Processing article ...  2007_0028 added to articles
# 	Processing author ...  Joaquim Madeira ( jmadeira@ua.pt  ) already in authors
# 	Processing form for author  Joaquim Madeira ...already in forms. Add article  2007_0028
# 	Processing author ...  Samuel Silva ( sss@ua.pt ) already in authors
# 	Processing form for author  Samuel Silva ...already in forms. Add article  2007_0028
# 	Processing author ...  André Stork ( andre.stork@igd.fhg.de  ) added to authors
# 	Processing form for author  André Stork ...added to forms. Add article  2007_0028
# 	Processing author ...  Sebastian Peña Serna ( sebastian.pena.serna@igd.fhg.de  ) added to authors
# 	Processing form for author  Sebastian Peña Serna ...added to forms. Add article  2007_0028
#
# Processing article ...  2007_0030 added to articles
# 	Processing author ...  Ricardo Gamboa ( rjssg@immi.inesc.pt  ) added to authors
# 	Processing form for author  Ricardo Gamboa ...added to forms. Add article  2007_0030
# 	Processing author ...  Vasco Costa ( vasco.costa@ist.utl.pt  ) already in authors
# 	Processing form for author  Vasco Costa ...already in forms. Add article  2007_0030
#
# Processing article ...  2007_0031 added to articles
# 	Processing author ...  Francisco Pires (  francisco.pires@iscte.pt  ) added to authors
# 	Processing form for author  Francisco Pires ...added to forms. Add article  2007_0031
# 	Processing author ...  M. S. Dias ( miguel.dias@microsoft.com ) added to authors
# 	Processing form for author  M. S. Dias ...added to forms. Add article  2007_0031
#
# Processing article ...  2007_0032 added to articles
# 	Processing author ...  Rui Varela ( francisco.pires@iscte.pt  ) added to authors
# 	Processing form for author  Rui Varela ...added to forms. Add article  2007_0032
# 	Processing author ...  M. S. Dias ( miguel.dias@microsoft.com  ) already in authors
# 	Processing form for author  M. S. Dias ...already in forms. Add article  2007_0032
#
# Processing article ...  2007_0033 added to articles
# 	Processing author ...  Ricardo Abreu ( ricardolafabreu@gmail.com ) added to authors
# 	Processing form for author  Ricardo Abreu ...added to forms. Add article  2007_0033
# 	Processing author ...  Ana Paula Cláudio ( apc@di.fc.ul.pt  ) already in authors
# 	Processing form for author  Ana Paula Cláudio ...already in forms. Add article  2007_0033
# 	Processing author ...  Maria Beatriz Carmo ( bc@di.fc.ul.pt  ) already in authors
# 	Processing form for author  Maria Beatriz Carmo ...already in forms. Add article  2007_0033
#
# *** Finished file 2007EPCG ***

# %%
# pickle dump the data structures

if events_modified:
    with open(pkl_path+events_fn,"wb") as events_out:
        pickle.dump(events, events_out)

if articles_modified:
    with open(pkl_path+articles_fn,"wb") as articles_out:
        pickle.dump(articles, articles_out)
        
if authors_modified:
    with open(pkl_path+authors_fn,"wb") as authors_out:
        pickle.dump(authors, authors_out)

if art_aut_modified:
    with open(pkl_path+art_aut_fn,"wb") as art_aut_out:
        pickle.dump(art_aut, art_aut_out)

if forms_modified:
    with open(pkl_path+forms_fn,"wb") as forms_out:
        pickle.dump(forms, forms_out)

# %%
print ('That\'s all, folks')
